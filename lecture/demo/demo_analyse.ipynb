# %% [markdown]
# # Analysis

# %% [markdown]
# The main thing we'll go through today is analysis of the Demo Experiment data. We have data from 8 participants who completed the experiment.
#
# **Before we can start:**
#
# **a**) [Download the demographics data](demo_demog.csv) as a `.csv` file, and place it in a directory that makes sense for you (e.g., called "demo_analysis").
#
# **b**) [Download the stimuli](demo_stimuli.csv) as a `.csv` file, and place it in the same demo analysis folder.
#
# **c**) [Download the raw trials data](demo_data.zip) as a `.zip` file.
#
# **d**) Extract the `data` folder from the `.zip` file and put it in your demo analysis folder.
#
# **e**) Start a new R script in RStudio, and save the `.R` file to the demo analysis folder.
#
# After following these instructions, you should have a directory structure that looks something like this:
#
# ```
# demo_analysis
# ├─ data
# │  ├─ trials_p171220.csv
# │  ├─ trials_p203530.csv
# │  └─ ...
# ├─ analysis.R
# └─ demo_demog.csv
# └─ demo_stimuli.csv
# ```
#
# Once everyone has completed these steps, we'll begin...

# %% [markdown]
# ## Loading the Data

# %% [markdown]
# #### 1: Load the Relevant Libraries
#
# These are the libraries we'll use for the analysis. Each library has a comment explaining what we will use it for.

# %%
options(repr.plot.width=3.5, repr.plot.height=3)
library(ggplot2)
theme_set(theme_classic() + theme(legend.position="top"))

# %%
library(readr)    # for reading the data into R
library(purrr)    # for easily importing multiple files
library(dplyr)    # for wrangling data (e.g., adding/renaming columns)

library(ggplot2)  # for visualising data
# Out:
# Attaching package: 'dplyr'
#
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union

# %% [markdown]
# #### 2. Import the Demographic Data
#
# First, we import the demographics data. This gives us some details about the participants who took part.

# %%
demog <- read_csv("demo_demog.csv")
# Out:
# Rows: 9 Columns: 7
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr (4): participant_id, gender, dominant_hand, first_language
# dbl (3): age, frame_rate_Hz, total_time_secs
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %% [markdown]
# This will print some details about the columns imported. Let's have a look at the data we imported. We have some missing data, but enough information to report age and gender information.

# %%
demog
# Out:
#   participant_id age gender dominant_hand first_language frame_rate_Hz
# 1 p171220        18  female right         german         60.93062
# 2 p203530        23  female right         german         60.14155
# 3 p209846        23  male   right         german         59.94025
# 4 p215942        27  female right         other          59.85515
# 5 p233174        22  male   left          german               NA
# 6 p331426        20  female right         german         59.16292
# 7 p498198        22  female left          german         59.87221
# 8 p699576        20  male   right         german         60.02556
# 9 p908815        19  male   right         german         60.05083
#   total_time_secs
# 1  720.8187
# 2  544.3295
# 3  775.5403
# 4  734.7305
# 5  597.8216
# 6  784.9782
# 7  837.8138
# 8 1008.8191
# 9      -Inf

# %%
demog |> print()
# Out:
# # A tibble: 9 x 7
#   participant_id   age gender dominant_hand first_language frame_rate_Hz
#   <chr>          <dbl> <chr>  <chr>         <chr>                  <dbl>
# 1 p171220           18 female right         german                  60.9
# 2 p203530           23 female right         german                  60.1
# 3 p209846           23 male   right         german                  59.9
# 4 p215942           27 female right         other                   59.9
# 5 p233174           22 male   left          german                  NA
# 6 p331426           20 female right         german                  59.2
# 7 p498198           22 female left          german                  59.9
# 8 p699576           20 male   right         german                  60.0
# 9 p908815           19 male   right         german                  60.1
# # i 1 more variable: total_time_secs <dbl>

# %% [markdown]
# #### 3: Import the Stimuli
#
# Next we import the list of stimuli:

# %%
stim <- read_csv("demo_stimuli.csv")

stim
# Out:
# Rows: 300 Columns: 8
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr (3): condition, text, corr_ans
# dbl (4): item_nr, snd, ZipfSUBTLEX, word_len
# lgl (1): is_practice_trial
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
#     item_nr condition  text                 corr_ans is_practice_trial
# 1    1      word       Akzente              ralt     FALSE
# 2    1      pseudoword Unwante              lalt     FALSE
# 3    2      word       Drücker              ralt     FALSE
# 4    2      pseudoword quokker              lalt     FALSE
# 5    3      word       Erwachsener          ralt     FALSE
# 6    3      pseudoword Exzingsener          lalt     FALSE
# 7    4      word       Exorzisten           ralt     FALSE
# 8    4      pseudoword ucinzisten           lalt     FALSE
# 9    5      word       Fabel                ralt     FALSE
# 10   5      pseudoword Pafel                lalt     FALSE
# 11   6      word       Faulpelze            ralt     FALSE
# 12   6      pseudoword peigpelze            lalt     FALSE
# 13   7      word       Figuren              ralt     FALSE
# 14   7      pseudoword Gowuren              lalt     FALSE
# 15   8      word       Filigrane            ralt     FALSE
# 16   8      pseudoword Gisiblase            lalt     FALSE
# 17   9      word       Geschicke            ralt     FALSE
# 18   9      pseudoword neschonke            lalt     FALSE
# 19  10      word       Gondel               ralt     FALSE
# 20  10      pseudoword pändel               lalt     FALSE
# 21  11      word       Grabens              ralt     FALSE
# 22  11      pseudoword Phabert              lalt     FALSE
# 23  12      word       Jugendfreund         ralt     FALSE
# 24  12      pseudoword Kugendfrophs         lalt     FALSE
# 25  13      word       Kanaille             ralt     FALSE
# 26  13      pseudoword Kahästle             lalt     FALSE
# 27  14      word       Kanäle               ralt     FALSE
# 28  14      pseudoword Gamäse               lalt     FALSE
# 29  15      word       Kollegium            ralt     FALSE
# 30  15      pseudoword Toffegizu            lalt     FALSE
# ... ...     ...        ...                  ...      ...
# 271 136     word       wahnsinnig           ralt     FALSE
# 272 136     pseudoword wondrinnig           lalt     FALSE
# 273 137     word       wegkomme             ralt     FALSE
# 274 137     pseudoword weutamme             lalt     FALSE
# 275 138     word       wissenschaftlicheren ralt     FALSE
# 276 138     pseudoword mempenschelllicheren lalt     FALSE
# 277 139     word       wunderbaren          ralt     FALSE
# 278 139     pseudoword Vuljerwagen          lalt     FALSE
# 279 140     word       wundersamer          ralt     FALSE
# 280 140     pseudoword Austerbafer          lalt     FALSE
# 281 141     word       wunderschöne         ralt     FALSE
# 282 141     pseudoword pulderstrüse         lalt     FALSE
# 283 142     word       zackiger             ralt     FALSE
# 284 142     pseudoword zürgiger             lalt     FALSE
# 285 143     word       zerrinnen            ralt     FALSE
# 286 143     pseudoword zerfanken            lalt     FALSE
# 287 144     word       zeugt                ralt     FALSE
# 288 144     pseudoword zeggt                lalt     FALSE
# 289 145     word       zuflüstern           ralt     FALSE
# 290 145     pseudoword umdröstern           lalt     FALSE
# 291 146     word       zurechtgebogen       ralt     FALSE
# 292 146     pseudoword zunandsgewägen       lalt     FALSE
# 293 147     word       zurückgeschreckt     ralt     FALSE
# 294 147     pseudoword zurichgeschrafst     lalt     FALSE
# 295 148     word       überbelegt           ralt     FALSE
# 296 148     pseudoword iberfenerb           lalt     FALSE
# 297 149     word       überlebensgroße      ralt     FALSE
# 298 149     pseudoword überlefätsglave      lalt     FALSE
# 299 150     word       überlisten           ralt     FALSE
# 300 150     pseudoword otertesten           lalt     FALSE
#     snd       ZipfSUBTLEX word_len
# 1   0.7164028 2.71         7
# 2   0.5337820   NA         7
# 3   0.5730488 3.01         7
# 4   0.5511313   NA         7
# 5   0.6809480 3.95        11
# 6   0.5324633   NA        11
# 7   0.6235078 2.64        10
# 8   0.4170587   NA        10
# 9   0.6343845 2.60         5
# 10  0.5519994   NA         5
# 11  0.5894609 2.74         9
# 12  0.5777983   NA         9
# 13  0.7301291 4.38         7
# 14  0.5398612   NA         7
# 15  0.6749975 1.90         9
# 16  0.5315044   NA         9
# 17  0.4512565 2.07         9
# 18  0.4765813   NA         9
# 19  0.6947889 3.11         6
# 20  0.4685015   NA         6
# 21  0.7030543 1.90         7
# 22  0.4602155   NA         7
# 23  0.6942410 2.55        12
# 24  0.4639937   NA        12
# 25  0.6233634 2.44         8
# 26  0.5502094   NA         8
# 27  0.7313112 3.59         6
# 28  0.5696685   NA         6
# 29  0.6807463 2.67         9
# 30  0.5886507   NA         9
# ... ...       ...         ...
# 271 0.8447705 4.55        10
# 272 0.4723154   NA        10
# 273 0.6856961 2.85         8
# 274 0.4449381   NA         8
# 275 0.7608551 2.07        20
# 276 0.4630420   NA        20
# 277 0.8764615 3.87        11
# 278 0.5847260   NA        11
# 279 0.6839779 2.29        11
# 280 0.6162724   NA        11
# 281 0.8831501 4.16        12
# 282 0.5515038   NA        12
# 283 0.6673189 2.20         8
# 284 0.6080680   NA         8
# 285 0.6125055 1.90         9
# 286 0.5328117   NA         9
# 287 0.6530934 3.30         5
# 288 0.5036876   NA         5
# 289 0.7208457 2.64        10
# 290 0.4849664   NA        10
# 291 0.6257972 2.07        14
# 292 0.3937071   NA        14
# 293 0.6647302 1.90        16
# 294 0.4287635   NA        16
# 295 0.6246822 2.20        10
# 296 0.4673373   NA        10
# 297 0.7568407 1.90        15
# 298 0.6315054   NA        15
# 299 0.6474396 3.33        10
# 300 0.6183059   NA        10

# %%
stim |> print()
# Out:
# # A tibble: 300 x 8
#    item_nr condition text  corr_ans is_practice_trial   snd ZipfSUBTLEX word_len
#      <dbl> <chr>     <chr> <chr>    <lgl>             <dbl>       <dbl>    <dbl>
#  1       1 word      Akze~ ralt     FALSE             0.716        2.71        7
#  2       1 pseudowo~ Unwa~ lalt     FALSE             0.534       NA           7
#  3       2 word      Drüc~ ralt     FALSE             0.573        3.01        7
#  4       2 pseudowo~ quok~ lalt     FALSE             0.551       NA           7
#  5       3 word      Erwa~ ralt     FALSE             0.681        3.95       11
#  6       3 pseudowo~ Exzi~ lalt     FALSE             0.532       NA          11
#  7       4 word      Exor~ ralt     FALSE             0.624        2.64       10
#  8       4 pseudowo~ ucin~ lalt     FALSE             0.417       NA          10
#  9       5 word      Fabel ralt     FALSE             0.634        2.6         5
# 10       5 pseudowo~ Pafel lalt     FALSE             0.552       NA           5
# # i 290 more rows

# %% [markdown]
# This has 8 columns:
#
# * `item_nr` - an ID for each matched pair of words and pseudowords
#
# * `condition` - whether each item is a `"word"` or `"pseudoword"`
#
# * `text` - the text shown to the participant
#
# * `corr_ans` - whether the correct answer was to press the left alt key (`"lalt"`) or the right alt key (`"ralt"`)
#
# * `snd` - semantic neighbourhood density, calculated using the fastText model, using the method described by Hendrix & Sun ([2020](https://doi.org/10.1037/xlm0000819))
#
# * `ZipfSUBTLEX` - a measure of word frequency from a german subtitle corpus: SUBTLEX-DE (Bysbaert et al., [2011](https://doi.org/10.1027/1618-3169/a000123)). For more info on the "Zipf" measure, see Brysbaert et al. ([2017](
# https://doi.org/10.1177/096372141772752))
#
# * `word_len` - number of letters in the word / pseudoword

# %% [markdown]
# #### 4: Import the Raw Data
#
# Let's import the experiment data from the `data` folder:

# %%
# first, get a list of all .csv data files
data_paths <- list.files("data", pattern=".*\\.csv$", full.names=TRUE)

# now, iterate over these with `read_csv()` to import each
raw_data <- map_df(data_paths, read_csv)

# print the contents
raw_data
# Out:
# Rows: 310 Columns: 8
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr (4): participant_id, condition, text, resp
# dbl (3): item_nr, rt_ms, time_so_far_secs
# lgl (1): is_practice_trial
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 310 Columns: 8
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr (4): participant_id, condition, text, resp
# dbl (3): item_nr, rt_ms, time_so_far_secs
# lgl (1): is_practice_trial
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 310 Columns: 8
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr (4): participant_id, condition, text, resp
# dbl (3): item_nr, rt_ms, time_so_far_secs
# lgl (1): is_practice_trial
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 310 Columns: 8
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr (4): participant_id, condition, text, resp
# dbl (3): item_nr, rt_ms, time_so_far_secs
# lgl (1): is_practice_trial
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 310 Columns: 8
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr (4): participant_id, condition, text, resp
# dbl (3): item_nr, rt_ms, time_so_far_secs
# lgl (1): is_practice_trial
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 310 Columns: 8
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr (4): participant_id, condition, text, resp
# dbl (3): item_nr, rt_ms, time_so_far_secs
# lgl (1): is_practice_trial
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 310 Columns: 8
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr (4): participant_id, condition, text, resp
# dbl (3): item_nr, rt_ms, time_so_far_secs
# lgl (1): is_practice_trial
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 310 Columns: 8
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr (4): participant_id, condition, text, resp
# dbl (3): item_nr, rt_ms, time_so_far_secs
# lgl (1): is_practice_trial
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
#      participant_id item_nr condition  text                 is_practice_trial
# 1    p171220          4     pseudoword segt                  TRUE
# 2    p171220          4     word       sagt                  TRUE
# 3    p171220          5     pseudoword tobreren              TRUE
# 4    p171220          1     pseudoword Bage                  TRUE
# 5    p171220          3     pseudoword Torrerk               TRUE
# 6    p171220          3     word       korrekt               TRUE
# 7    p171220          2     pseudoword sanzes                TRUE
# 8    p171220          2     word       Mannes                TRUE
# 9    p171220          1     word       Haie                  TRUE
# 10   p171220          5     word       sicheren              TRUE
# 11   p171220        100     word       interpretiert        FALSE
# 12   p171220         45     word       Vertragsabschlüssen  FALSE
# 13   p171220         98     word       hinlege              FALSE
# 14   p171220         93     pseudoword wafspiges            FALSE
# 15   p171220        112     pseudoword oßmiziivsem          FALSE
# 16   p171220        149     pseudoword überlefätsglave      FALSE
# 17   p171220         87     pseudoword Cermelen             FALSE
# 18   p171220          6     word       Faulpelze            FALSE
# 19   p171220         57     pseudoword abbeßen              FALSE
# 20   p171220         22     word       Miene                FALSE
# 21   p171220         28     word       Rasters              FALSE
# 22   p171220         26     word       Parzellen            FALSE
# 23   p171220         96     pseudoword Klauchrertig         FALSE
# 24   p171220        119     pseudoword Schöchteckste        FALSE
# 25   p171220         16     word       Konstitution         FALSE
# 26   p171220         26     pseudoword ponzellen            FALSE
# 27   p171220          2     word       Drücker              FALSE
# 28   p171220         81     pseudoword emptöltig            FALSE
# 29   p171220         77     pseudoword bumsge               FALSE
# 30   p171220         19     word       Lobpreisung          FALSE
# ...  ...            ...     ...        ...                  ...
# 2451 p699576        114     pseudoword messelt              FALSE
# 2452 p699576        140     pseudoword Austerbafer          FALSE
# 2453 p699576         56     word       angezogen            FALSE
# 2454 p699576         64     word       aufschrecken         FALSE
# 2455 p699576         82     word       entgegenkommende     FALSE
# 2456 p699576         69     pseudoword benäugen             FALSE
# 2457 p699576        109     word       naturalistischen     FALSE
# 2458 p699576         25     pseudoword Pachtaftagen         FALSE
# 2459 p699576         89     pseudoword feckst               FALSE
# 2460 p699576         97     word       haltmachen           FALSE
# 2461 p699576        106     pseudoword lebensrorgtich       FALSE
# 2462 p699576        133     word       verzeichnet          FALSE
# 2463 p699576        125     pseudoword Sevewoknischen       FALSE
# 2464 p699576         40     pseudoword ponaobeumer          FALSE
# 2465 p699576        115     pseudoword nezolierten          FALSE
# 2466 p699576         37     pseudoword spraxenwäschen       FALSE
# 2467 p699576         50     pseudoword Bünktchen            FALSE
# 2468 p699576         29     pseudoword Rechtsfissenstrent   FALSE
# 2469 p699576        117     pseudoword schrordelte          FALSE
# 2470 p699576        101     word       jahrelanges          FALSE
# 2471 p699576         29     word       Rechtswissenschaft   FALSE
# 2472 p699576        121     word       sogleich             FALSE
# 2473 p699576         66     word       aufwendig            FALSE
# 2474 p699576        129     pseudoword verligtet            FALSE
# 2475 p699576        105     word       lateinamerikanischer FALSE
# 2476 p699576         22     pseudoword Tieme                FALSE
# 2477 p699576         18     word       Kreuzzug             FALSE
# 2478 p699576         23     pseudoword kidefutwe            FALSE
# 2479 p699576        123     pseudoword Sprommen             FALSE
# 2480 p699576         27     pseudoword dükken               FALSE
#      resp rt_ms     time_so_far_secs
# 1    lalt  887.1145  34.90737
# 2    ralt  682.5982  37.31386
# 3    lalt  751.4031  39.54651
# 4    lalt  529.5305  41.86358
# 5    lalt  551.4779  43.93993
# 6    ralt  489.4925  46.05284
# 7    lalt  455.5583  48.10536
# 8    lalt  565.0679  50.11874
# 9    ralt  632.8114  52.23046
# 10   ralt  588.5707  54.41275
# 11   ralt  609.5713  61.89227
# 12   ralt 2005.7603  63.50745
# 13   ralt 2236.9945  66.53842
# 14   lalt  686.1174  69.80176
# 15   lalt  488.3721  71.51442
# 16   lalt  557.4629  73.02936
# 17   lalt 1716.3446  74.61313
# 18   ralt  665.3860  77.35919
# 19   lalt  849.3609  79.04114
# 20   ralt  938.8370  80.90572
# 21   lalt 1705.7095  82.87152
# 22   ralt 3048.4637  85.59989
# 23   lalt 1402.8554  89.67909
# 24   lalt 1283.4721  92.10889
# 25   ralt  704.7322  94.42319
# 26   lalt 1160.4696  96.15473
# 27   ralt  838.5844  98.33636
# 28   lalt  731.6157 100.20017
# 29   lalt  732.4343 101.94821
# 30   ralt 1035.8145 103.69617
# ...  ...  ...       ...
# 2451 ralt  535.4823  959.7664
# 2452 lalt  605.0096  961.3329
# 2453 ralt  692.2376  962.9663
# 2454 ralt  557.5437  964.6795
# 2455 lalt  668.4817  966.2631
# 2456 lalt  781.0378  967.9637
# 2457 ralt  580.4705  969.7631
# 2458 lalt  592.9715  971.3634
# 2459 ralt  539.0508  972.9640
# 2460 ralt  637.3448  974.5135
# 2461 lalt  784.9005  976.1799
# 2462 ralt  765.9475  977.9978
# 2463 lalt  548.4392  979.7816
# 2464 lalt  566.4637  981.3331
# 2465 lalt  723.6252  982.9011
# 2466 lalt  662.3804  984.6511
# 2467 lalt  760.5160  986.3343
# 2468 lalt 1456.3451  988.1181
# 2469 lalt  615.0866  990.6014
# 2470 ralt  715.4233  992.2348
# 2471 ralt  527.8703  993.9683
# 2472 ralt  745.2882  995.5183
# 2473 ralt  467.0031  997.2853
# 2474 lalt  576.0861  998.7685
# 2475 ralt  750.5350 1000.3685
# 2476 lalt  699.4003 1002.1522
# 2477 ralt  685.4513 1003.8688
# 2478 lalt  601.8988 1005.5856
# 2479 lalt  568.3368 1007.2191
# 2480 lalt  595.3683 1008.8191

# %%
raw_data |> print()
# Out:
# # A tibble: 2,480 x 8
#    participant_id item_nr condition  text     is_practice_trial resp  rt_ms
#    <chr>            <dbl> <chr>      <chr>    <lgl>             <chr> <dbl>
#  1 p171220              4 pseudoword segt     TRUE              lalt   887.
#  2 p171220              4 word       sagt     TRUE              ralt   683.
#  3 p171220              5 pseudoword tobreren TRUE              lalt   751.
#  4 p171220              1 pseudoword Bage     TRUE              lalt   530.
#  5 p171220              3 pseudoword Torrerk  TRUE              lalt   551.
#  6 p171220              3 word       korrekt  TRUE              ralt   489.
#  7 p171220              2 pseudoword sanzes   TRUE              lalt   456.
#  8 p171220              2 word       Mannes   TRUE              lalt   565.
#  9 p171220              1 word       Haie     TRUE              ralt   633.
# 10 p171220              5 word       sicheren TRUE              ralt   589.
# # i 2,470 more rows
# # i 1 more variable: time_so_far_secs <dbl>

# %% [markdown]
# This gives us one data frame with all trials in the experiment.
#
# There are 9 columns of data:
#
# * `participant_id` - a unique ID for each paricipant
#
# * `item_nr`- the same item ID as in `stim`
#
# * `condition` - whether the trial showed a `"word"` or `"pseudoword"`
#
# * `text` - the text that the participant saw
#
# * `is_practice_trial` - whether each trial was a practice trial. The first 10 trials for each participant will be practice trials.
#
# * `resp` - left alt key (`"lalt"`) or the right alt key (`"ralt"`)

# %% [markdown]
# #### 5: Join the Data Together
#
# The easiest way to work with small datasets like this is to just join the dataframes together. This will create some redundancy (e.g., participant ages will be repeated 300 times), but can make things easier to work with.
#
# Here we use `left_join()` to find add information about participant demographics and features of the stimuli. This identifies rows that the dataframes have in common, and joins them togeher. Notice that we now have one big dataframe with all of the information about every trial.

# %%
all_dat <- raw_data |>
  left_join(demog) |>
  left_join(stim)
# Out:
# Joining with `by = join_by(participant_id)`
# Joining with `by = join_by(item_nr, condition, text, is_practice_trial)`

# %%
all_dat
# Out:
#      participant_id item_nr condition  text                 is_practice_trial
# 1    p171220          4     pseudoword segt                  TRUE
# 2    p171220          4     word       sagt                  TRUE
# 3    p171220          5     pseudoword tobreren              TRUE
# 4    p171220          1     pseudoword Bage                  TRUE
# 5    p171220          3     pseudoword Torrerk               TRUE
# 6    p171220          3     word       korrekt               TRUE
# 7    p171220          2     pseudoword sanzes                TRUE
# 8    p171220          2     word       Mannes                TRUE
# 9    p171220          1     word       Haie                  TRUE
# 10   p171220          5     word       sicheren              TRUE
# 11   p171220        100     word       interpretiert        FALSE
# 12   p171220         45     word       Vertragsabschlüssen  FALSE
# 13   p171220         98     word       hinlege              FALSE
# 14   p171220         93     pseudoword wafspiges            FALSE
# 15   p171220        112     pseudoword oßmiziivsem          FALSE
# 16   p171220        149     pseudoword überlefätsglave      FALSE
# 17   p171220         87     pseudoword Cermelen             FALSE
# 18   p171220          6     word       Faulpelze            FALSE
# 19   p171220         57     pseudoword abbeßen              FALSE
# 20   p171220         22     word       Miene                FALSE
# 21   p171220         28     word       Rasters              FALSE
# 22   p171220         26     word       Parzellen            FALSE
# 23   p171220         96     pseudoword Klauchrertig         FALSE
# 24   p171220        119     pseudoword Schöchteckste        FALSE
# 25   p171220         16     word       Konstitution         FALSE
# 26   p171220         26     pseudoword ponzellen            FALSE
# 27   p171220          2     word       Drücker              FALSE
# 28   p171220         81     pseudoword emptöltig            FALSE
# 29   p171220         77     pseudoword bumsge               FALSE
# 30   p171220         19     word       Lobpreisung          FALSE
# ...  ...            ...     ...        ...                  ...
# 2451 p699576        114     pseudoword messelt              FALSE
# 2452 p699576        140     pseudoword Austerbafer          FALSE
# 2453 p699576         56     word       angezogen            FALSE
# 2454 p699576         64     word       aufschrecken         FALSE
# 2455 p699576         82     word       entgegenkommende     FALSE
# 2456 p699576         69     pseudoword benäugen             FALSE
# 2457 p699576        109     word       naturalistischen     FALSE
# 2458 p699576         25     pseudoword Pachtaftagen         FALSE
# 2459 p699576         89     pseudoword feckst               FALSE
# 2460 p699576         97     word       haltmachen           FALSE
# 2461 p699576        106     pseudoword lebensrorgtich       FALSE
# 2462 p699576        133     word       verzeichnet          FALSE
# 2463 p699576        125     pseudoword Sevewoknischen       FALSE
# 2464 p699576         40     pseudoword ponaobeumer          FALSE
# 2465 p699576        115     pseudoword nezolierten          FALSE
# 2466 p699576         37     pseudoword spraxenwäschen       FALSE
# 2467 p699576         50     pseudoword Bünktchen            FALSE
# 2468 p699576         29     pseudoword Rechtsfissenstrent   FALSE
# 2469 p699576        117     pseudoword schrordelte          FALSE
# 2470 p699576        101     word       jahrelanges          FALSE
# 2471 p699576         29     word       Rechtswissenschaft   FALSE
# 2472 p699576        121     word       sogleich             FALSE
# 2473 p699576         66     word       aufwendig            FALSE
# 2474 p699576        129     pseudoword verligtet            FALSE
# 2475 p699576        105     word       lateinamerikanischer FALSE
# 2476 p699576         22     pseudoword Tieme                FALSE
# 2477 p699576         18     word       Kreuzzug             FALSE
# 2478 p699576         23     pseudoword kidefutwe            FALSE
# 2479 p699576        123     pseudoword Sprommen             FALSE
# 2480 p699576         27     pseudoword dükken               FALSE
#      resp rt_ms     time_so_far_secs age gender dominant_hand first_language
# 1    lalt  887.1145  34.90737        18  female right         german
# 2    ralt  682.5982  37.31386        18  female right         german
# 3    lalt  751.4031  39.54651        18  female right         german
# 4    lalt  529.5305  41.86358        18  female right         german
# 5    lalt  551.4779  43.93993        18  female right         german
# 6    ralt  489.4925  46.05284        18  female right         german
# 7    lalt  455.5583  48.10536        18  female right         german
# 8    lalt  565.0679  50.11874        18  female right         german
# 9    ralt  632.8114  52.23046        18  female right         german
# 10   ralt  588.5707  54.41275        18  female right         german
# 11   ralt  609.5713  61.89227        18  female right         german
# 12   ralt 2005.7603  63.50745        18  female right         german
# 13   ralt 2236.9945  66.53842        18  female right         german
# 14   lalt  686.1174  69.80176        18  female right         german
# 15   lalt  488.3721  71.51442        18  female right         german
# 16   lalt  557.4629  73.02936        18  female right         german
# 17   lalt 1716.3446  74.61313        18  female right         german
# 18   ralt  665.3860  77.35919        18  female right         german
# 19   lalt  849.3609  79.04114        18  female right         german
# 20   ralt  938.8370  80.90572        18  female right         german
# 21   lalt 1705.7095  82.87152        18  female right         german
# 22   ralt 3048.4637  85.59989        18  female right         german
# 23   lalt 1402.8554  89.67909        18  female right         german
# 24   lalt 1283.4721  92.10889        18  female right         german
# 25   ralt  704.7322  94.42319        18  female right         german
# 26   lalt 1160.4696  96.15473        18  female right         german
# 27   ralt  838.5844  98.33636        18  female right         german
# 28   lalt  731.6157 100.20017        18  female right         german
# 29   lalt  732.4343 101.94821        18  female right         german
# 30   ralt 1035.8145 103.69617        18  female right         german
# ...  ...  ...       ...              ... ...    ...           ...
# 2451 ralt  535.4823  959.7664        20  male   right         german
# 2452 lalt  605.0096  961.3329        20  male   right         german
# 2453 ralt  692.2376  962.9663        20  male   right         german
# 2454 ralt  557.5437  964.6795        20  male   right         german
# 2455 lalt  668.4817  966.2631        20  male   right         german
# 2456 lalt  781.0378  967.9637        20  male   right         german
# 2457 ralt  580.4705  969.7631        20  male   right         german
# 2458 lalt  592.9715  971.3634        20  male   right         german
# 2459 ralt  539.0508  972.9640        20  male   right         german
# 2460 ralt  637.3448  974.5135        20  male   right         german
# 2461 lalt  784.9005  976.1799        20  male   right         german
# 2462 ralt  765.9475  977.9978        20  male   right         german
# 2463 lalt  548.4392  979.7816        20  male   right         german
# 2464 lalt  566.4637  981.3331        20  male   right         german
# 2465 lalt  723.6252  982.9011        20  male   right         german
# 2466 lalt  662.3804  984.6511        20  male   right         german
# 2467 lalt  760.5160  986.3343        20  male   right         german
# 2468 lalt 1456.3451  988.1181        20  male   right         german
# 2469 lalt  615.0866  990.6014        20  male   right         german
# 2470 ralt  715.4233  992.2348        20  male   right         german
# 2471 ralt  527.8703  993.9683        20  male   right         german
# 2472 ralt  745.2882  995.5183        20  male   right         german
# 2473 ralt  467.0031  997.2853        20  male   right         german
# 2474 lalt  576.0861  998.7685        20  male   right         german
# 2475 ralt  750.5350 1000.3685        20  male   right         german
# 2476 lalt  699.4003 1002.1522        20  male   right         german
# 2477 ralt  685.4513 1003.8688        20  male   right         german
# 2478 lalt  601.8988 1005.5856        20  male   right         german
# 2479 lalt  568.3368 1007.2191        20  male   right         german
# 2480 lalt  595.3683 1008.8191        20  male   right         german
#      frame_rate_Hz total_time_secs corr_ans snd       ZipfSUBTLEX word_len
# 1    60.93062      720.8187        NA              NA   NA        NA
# 2    60.93062      720.8187        NA              NA   NA        NA
# 3    60.93062      720.8187        NA              NA   NA        NA
# 4    60.93062      720.8187        NA              NA   NA        NA
# 5    60.93062      720.8187        NA              NA   NA        NA
# 6    60.93062      720.8187        NA              NA   NA        NA
# 7    60.93062      720.8187        NA              NA   NA        NA
# 8    60.93062      720.8187        NA              NA   NA        NA
# 9    60.93062      720.8187        NA              NA   NA        NA
# 10   60.93062      720.8187        NA              NA   NA        NA
# 11   60.93062      720.8187        ralt     0.7429246 3.29        13
# 12   60.93062      720.8187        ralt     0.6929057 1.90        19
# 13   60.93062      720.8187        ralt     0.6255987 2.67         7
# 14   60.93062      720.8187        lalt     0.6185039   NA         9
# 15   60.93062      720.8187        lalt     0.3327351   NA        11
# 16   60.93062      720.8187        lalt     0.6315054   NA        15
# 17   60.93062      720.8187        lalt     0.5477454   NA         8
# 18   60.93062      720.8187        ralt     0.5894609 2.74         9
# 19   60.93062      720.8187        lalt     0.5074726   NA         7
# 20   60.93062      720.8187        ralt     0.5955802 3.29         5
# 21   60.93062      720.8187        ralt     0.6336024 2.37         7
# 22   60.93062      720.8187        ralt     0.7221180 2.07         9
# 23   60.93062      720.8187        lalt     0.5380428   NA        12
# 24   60.93062      720.8187        lalt     0.4932567   NA        13
# 25   60.93062      720.8187        ralt     0.5881353 2.83        12
# 26   60.93062      720.8187        lalt     0.5538102   NA         9
# 27   60.93062      720.8187        ralt     0.5730488 3.01         7
# 28   60.93062      720.8187        lalt     0.4592212   NA         9
# 29   60.93062      720.8187        lalt     0.5324417   NA         6
# 30   60.93062      720.8187        ralt     0.6400776 1.90        11
# ...  ...           ...             ...      ...       ...         ...
# 2451 60.02556      1008.819        lalt     0.5852153   NA         7
# 2452 60.02556      1008.819        lalt     0.6162724   NA        11
# 2453 60.02556      1008.819        ralt     0.6679317 4.34         9
# 2454 60.02556      1008.819        ralt     0.6584207 2.37        12
# 2455 60.02556      1008.819        ralt     0.6470507 1.90        16
# 2456 60.02556      1008.819        lalt     0.5029023   NA         8
# 2457 60.02556      1008.819        ralt     0.6965252 2.29        16
# 2458 60.02556      1008.819        lalt     0.5562344   NA        12
# 2459 60.02556      1008.819        lalt     0.5333251   NA         6
# 2460 60.02556      1008.819        ralt     0.5936862 2.29        10
# 2461 60.02556      1008.819        lalt     0.5361782   NA        14
# 2462 60.02556      1008.819        ralt     0.7002903 3.19        11
# 2463 60.02556      1008.819        lalt     0.5932359   NA        14
# 2464 60.02556      1008.819        lalt     0.6096175   NA        11
# 2465 60.02556      1008.819        lalt     0.5406713   NA        11
# 2466 60.02556      1008.819        lalt     0.4860539   NA        14
# 2467 60.02556      1008.819        lalt     0.5853792   NA         9
# 2468 60.02556      1008.819        lalt     0.5349532   NA        18
# 2469 60.02556      1008.819        lalt     0.5026658   NA        11
# 2470 60.02556      1008.819        ralt     0.7446261 2.60        11
# 2471 60.02556      1008.819        ralt     0.7226302 2.07        18
# 2472 60.02556      1008.819        ralt     0.7475101 2.94         8
# 2473 60.02556      1008.819        ralt     0.8204466 2.50         9
# 2474 60.02556      1008.819        lalt     0.5021545   NA         9
# 2475 60.02556      1008.819        ralt     0.6354304 1.90        20
# 2476 60.02556      1008.819        lalt     0.5852154   NA         5
# 2477 60.02556      1008.819        ralt     0.6723947 3.21         8
# 2478 60.02556      1008.819        lalt     0.4394278   NA         9
# 2479 60.02556      1008.819        lalt     0.5493023   NA         8
# 2480 60.02556      1008.819        lalt     0.5516306   NA         6

# %%
all_dat |> print()
# Out:
# # A tibble: 2,480 x 18
#    participant_id item_nr condition  text     is_practice_trial resp  rt_ms
#    <chr>            <dbl> <chr>      <chr>    <lgl>             <chr> <dbl>
#  1 p171220              4 pseudoword segt     TRUE              lalt   887.
#  2 p171220              4 word       sagt     TRUE              ralt   683.
#  3 p171220              5 pseudoword tobreren TRUE              lalt   751.
#  4 p171220              1 pseudoword Bage     TRUE              lalt   530.
#  5 p171220              3 pseudoword Torrerk  TRUE              lalt   551.
#  6 p171220              3 word       korrekt  TRUE              ralt   489.
#  7 p171220              2 pseudoword sanzes   TRUE              lalt   456.
#  8 p171220              2 word       Mannes   TRUE              lalt   565.
#  9 p171220              1 word       Haie     TRUE              ralt   633.
# 10 p171220              5 word       sicheren TRUE              ralt   589.
# # i 2,470 more rows
# # i 11 more variables: time_so_far_secs <dbl>, age <dbl>, gender <chr>,
# #   dominant_hand <chr>, first_language <chr>, frame_rate_Hz <dbl>,
# #   total_time_secs <dbl>, corr_ans <chr>, snd <dbl>, ZipfSUBTLEX <dbl>,
# #   word_len <dbl>

# %% [markdown]
# ## Cleaning Data
#
# Now that we have the data loaded and all in one place, we need to exclude participants and trials that do not meet our exclusion criteria. This can be a useful step for (e.g.,) catching participants who were not paying attention, or removing outliers from your data.
#
# Before the experiment, I decided to exclude:
#
# * participants who had average accuracies <= 75% (too inaccurate)
#
# * participants who had median response times <250 ms (too fast)
#
# * participants who had median response times >1500 ms (too slow)
#
# * participants whose first language is not German
#
# * practice trials
#
# * trials responded to incorrectly (as we are interested in response times only in our analysis)
#
# #### 1: Calculate Accuracies
#
# First, let's create a column of participant accuracies. Wherever the `resp` column is equal to the `corr_ans` column, we will put a 1. Otherwise, we will put a zero.

# %%
all_dat <- mutate(all_dat, accuracy = ifelse(corr_ans == resp, 1, 0))

# %% [markdown]
# #### 2: Summarise Participants
#
# Now, we want to calculate per average response time and accuracy for each participant. Since response time is such a skewed distribution, we will calculate the median for response times.
#
# > Note: We include `first_language` in `group_by()` so that this is included in the per-participant summary, even though each participant has only one value.

# %%
participant_avg <- all_dat |>
  # exclude practice trials
  filter(!is_practice_trial) |>
  # then, for each participant, record their first language, and
  group_by(participant_id, first_language) |>
  # get their average RT and accuracy
  summarise(
    median_rt = median(rt_ms),
    mean_acc = mean(accuracy)
  ) |>
  # (often good practice to ungroup)
  ungroup()

participant_avg
# Out:
# `summarise()` has grouped output by 'participant_id'. You can override using
# the `.groups` argument.
#   participant_id first_language median_rt mean_acc
# 1 p171220        german          741.9733 0.9566667
# 2 p203530        german          540.0705 0.9400000
# 3 p209846        german          977.2635 0.9200000
# 4 p215942        other          1000.5606 0.8966667
# 5 p233174        german          596.6183 0.8633333
# 6 p331426        german          762.4101 0.9400000
# 7 p498198        german          792.4349 0.9566667
# 8 p699576        german          624.2055 0.9000000

# %%
participant_avg |> print()
# Out:
# # A tibble: 8 x 4
#   participant_id first_language median_rt mean_acc
#   <chr>          <chr>              <dbl>    <dbl>
# 1 p171220        german              742.    0.957
# 2 p203530        german              540.    0.94
# 3 p209846        german              977.    0.92
# 4 p215942        other              1001.    0.897
# 5 p233174        german              597.    0.863
# 6 p331426        german              762.    0.94
# 7 p498198        german              792.    0.957
# 8 p699576        german              624.    0.9

# %% [markdown]
# #### 3: Identify Good Participants
#
# Now, we can identify participants which are suitable for our hypotheses. When I originally designed the experiment, I decided to include:
#
# * only participants who had accuracies and response times within our cutoffs
#
# * only participants whose first language is German
#
# Here, we filter the dataframe of participant averages, and then make not of all the participants who meet our criteria. We store the list of good participants in `okay_participants`.
#
# > Note: the `pull()` function extracts data from a column, and puts it in a vector for us

# %%
okay_participants <- participant_avg |>
  filter(mean_acc>0.75, median_rt>=250, median_rt<1500, first_language=="german") |>
  pull(participant_id)

okay_participants
# Out:
# [1] "p171220" "p203530" "p209846" "p233174" "p331426" "p498198" "p699576"

# %% [markdown]
# #### 4: Clean Data
#
# Now we:
#
# * apply our participant exclusions
#
# * exclude trials that were responded to incorrectly
#
# * exclude practice trials
#
# We store the trials which we will use in the analysis in `trials_clean`

# %%
trials_clean <- all_dat |>
  filter(
    # only keep participants that meet inclusion criteria
    participant_id %in% okay_participants,
    # only keep correct trials
    accuracy == 1,
    # remove practice trials
    # (note: the exclamation mark ! can be read as "is not")
    !is_practice_trial
  )

# %% [markdown]
# ## Analysis - Frequency Effect
#
# Can we replicate the effect of frequency? Let's see what the effect of Zipf is on lexical decision response times!
#
# #### 1: Calculate Word Averages
#
# Here, we calculate the average RT and accuracy for each word. We also make sure that the Zipf values are brought through by including them in the `group_by()` function.

# %%
word_averages <- trials_clean |>
  filter(condition == "word") |>
  group_by(text, ZipfSUBTLEX) |>
  summarise(
    median_rt = median(rt_ms),
    mean_acc = mean(accuracy)
  ) |>
  ungroup()

word_averages
# Out:
# `summarise()` has grouped output by 'text'. You can override using the
# `.groups` argument.
#     text                 ZipfSUBTLEX median_rt mean_acc
# 1   Akzente              2.71        628.2463  1
# 2   Drücker              3.01        598.8304  1
# 3   Erwachsener          3.95        636.2265  1
# 4   Exorzisten           2.64        744.7074  1
# 5   Fabel                2.60        641.4402  1
# 6   Faulpelze            2.74        602.9854  1
# 7   Figuren              4.38        525.4853  1
# 8   Filigrane            1.90        970.5680  1
# 9   Geschicke            2.07        717.0423  1
# 10  Gondel               3.11        697.9093  1
# 11  Grabens              1.90        633.8906  1
# 12  Jugendfreund         2.55        607.3293  1
# 13  Kanaille             2.44        917.6175  1
# 14  Kanäle               3.59        575.7610  1
# 15  Kollegium            2.67        660.3516  1
# 16  Konstitution         2.83        599.5268  1
# 17  Kontoauszug          2.29        617.9452  1
# 18  Kreuzzug             3.21        600.0366  1
# 19  Lobpreisung          1.90        753.0777  1
# 20  Maulwurf             3.68        517.5854  1
# 21  Media                4.30        615.2128  1
# 22  Miene                3.29        650.2629  1
# 23  Modepuppe            2.20        846.9598  1
# 24  Mühle                3.55        626.4183  1
# 25  Nachmittagen         2.07        633.3145  1
# 26  Parzellen            2.07        879.9894  1
# 27  Pocken               3.07        634.4978  1
# 28  Rasters              2.37        576.9294  1
# 29  Rechtswissenschaft   2.07        628.3574  1
# 30  Röntgen              3.53        694.8907  1
# ... ...                  ...         ...       ...
# 121 sogleich             2.94         794.8093 1
# 122 spuckten             2.44         593.1715 1
# 123 strammen             2.60         609.4429 1
# 124 sympathisierst       2.20         937.1305 1
# 125 telepathischen       2.29         796.3128 1
# 126 undurchdringbar      2.37         807.1652 1
# 127 ungesetzlich         2.83         652.0041 1
# 128 verantwortungsvollen 2.20         985.2642 1
# 129 vergeltet            2.07         573.8220 1
# 130 verkürzen            3.01         588.7034 1
# 131 verschmutzen         2.74         612.3274 1
# 132 versteigere          1.90         564.1581 1
# 133 verzeichnet          3.19         764.3696 1
# 134 verzieren            2.50         757.5855 1
# 135 vorschriftswidrig    2.20        1074.7448 1
# 136 wahnsinnig           4.55         649.1393 1
# 137 wegkomme             2.85         618.5577 1
# 138 wissenschaftlicheren 2.07         757.7554 1
# 139 wunderbaren          3.87         572.3919 1
# 140 wundersamer          2.29         626.9146 1
# 141 wunderschöne         4.16         622.3625 1
# 142 zackiger             2.20         744.7399 1
# 143 zerrinnen            1.90        1007.1192 1
# 144 zeugt                3.30         520.3588 1
# 145 zuflüstern           2.64         742.6786 1
# 146 zurechtgebogen       2.07        1018.8596 1
# 147 zurückgeschreckt     1.90         979.5155 1
# 148 überbelegt           2.20         825.6721 1
# 149 überlebensgroße      1.90         692.0386 1
# 150 überlisten           3.33         705.1275 1

# %%
word_averages |> print()
# Out:
# # A tibble: 150 x 4
#    text        ZipfSUBTLEX median_rt mean_acc
#    <chr>             <dbl>     <dbl>    <dbl>
#  1 Akzente            2.71      628.        1
#  2 Drücker            3.01      599.        1
#  3 Erwachsener        3.95      636.        1
#  4 Exorzisten         2.64      745.        1
#  5 Fabel              2.6       641.        1
#  6 Faulpelze          2.74      603.        1
#  7 Figuren            4.38      525.        1
#  8 Filigrane          1.9       971.        1
#  9 Geschicke          2.07      717.        1
# 10 Gondel             3.11      698.        1
# # i 140 more rows

# %% [markdown]
# Clearly, accuracy is overall very high, but we have some variability in the response times.
#
# #### 2: Code the Frequency Variable
#
# Word frequency (`ZipfSUBTLEX`) is stored as a continuous variable. We can fit our model without doing any coding, but then it will be harder to interpret our model intercept. It is often useful to mean-centre variables, so that the model intercept can be interpreted as the grand average (e.g., the average RT overall).
#
# Let's calculate mean-centred Zipf frequency, and store in `ZipfSUBTLEX_cent`.

# %%
word_averages <- word_averages |>
  mutate(ZipfSUBTLEX_cent = ZipfSUBTLEX - mean(ZipfSUBTLEX))

# %% [markdown]
# #### 3: Estimate the Frequency Effect
#
# Now we can fit a linear model to predict average item response times as a function of mean-centred word frequency.

# %%
freq_mod <- lm(median_rt ~ ZipfSUBTLEX_cent, data = word_averages)

summary(freq_mod)
# Out:
# Call:
# lm(formula = median_rt ~ ZipfSUBTLEX_cent, data = word_averages)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -237.96  -92.19  -15.80   52.61  476.65
#
# Coefficients:
#                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)        682.95      10.35  66.007  < 2e-16 ***
# ZipfSUBTLEX_cent   -71.20      10.45  -6.813 2.24e-10 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 126.7 on 148 degrees of freedom
# Multiple R-squared:  0.2388,	Adjusted R-squared:  0.2336
# F-statistic: 46.42 on 1 and 148 DF,  p-value: 2.243e-10

# %% [markdown]
# This tells us that the average RT overall was 682.95 ms (*SE* = 10.35). The *t* value of >66 just reflects that this number is much larger than zero. We would report the overall average RT, but we probably wouldn't report the *t* and *p* values for this, since RT is almost by definition larger than zero.
#
# The second coefficient is more interesting. The $\Beta$ = -71.2 (*SE* = 10.45) tells us that for every one unit of Zipf, RT becomes 71.2 ms faster on average. This effect is significantly different from zero (*t*(148) = -6.81, *p* < .001).
#
# We might also want to report the R$^2$ value of .24, which means that our model is accounting for an estimated 24% of variance in the data.
#
# Finally, we might want to make a nice plot of the effect. We will be spending more time on this in a future session, but here is an example, showing the effect of frequency on response time.

# %%
word_averages |>
  ggplot(aes(ZipfSUBTLEX, median_rt)) +
  geom_point() +
  geom_smooth(method = "lm", formula = y~x) +
  labs(
    x = "Frequency (Zipf in SUBTLEX-DE)",
    y = "Median Response Time (ms)"
  )
# Out:
# plot without title

# %% [markdown]
# ## Analysis - SND Effects
#
# The main reason we ran this experiment, though, was to see whether we could replicate the interaction between Lexicality (word / pseudoword) and SND (semantic neighbourhood density).
#
# #### 1: Calculate Item Averages
#
# As before, we want to calculate average response times for each item. However, we also now want to include the pseudowords, as well as the words.
#
# We also want to include a step reported by Hendrix and Sun, who excluded items with an average accuracy of 66% or less.

# %%
stim_averages <- trials_clean |>
  # for every unique stimulus (text shown to the participant),
  # while also storing condition (lexicality) and SND,
  group_by(text, condition, snd) |>
  # get the average RT and accuracy
  summarise(
    median_rt = median(rt_ms),
    mean_acc = mean(accuracy)
  ) |>
  ungroup()
# Out:
# `summarise()` has grouped output by 'text', 'condition'. You can override using
# the `.groups` argument.

# %% [markdown]
# #### 2: Code Variables
#
# Again, we now want to code the variables.
#
# SND is a continuous variable, so we will mean-centre it (`snd_cent`). (We could also scale it if we wanted stardised coefficients.)
#
# Lexicality is a categorical variable, which we will deviation-code (`dev_lex`). If we had perfectly equal numbers of words and pseudowords in the data, we could just set this to `-0.5` and `0.5`. However, since we *might* have unequal numbers, to make sure that the variable is centred on zero, we first dummy code to 0 and 1, and then mean-centre it. As we happen to have equal numbers of stimuli, the values end up being `-0.5` and `0.5` anyway.

# %%
stim_averages <- stim_averages |>
  mutate(
    snd_cent = snd - mean(snd),
    dum_lex = ifelse(condition == "word", 1, 0),
    dev_lex = dum_lex - mean(dum_lex)
  )

stim_averages
# Out:
#     text                 condition  snd       median_rt mean_acc snd_cent
# 1   Abgegöbe             pseudoword 0.6138101  942.4915 1         0.01042202
# 2   Akzente              word       0.7164028  628.2463 1         0.11301472
# 3   Austerbafer          pseudoword 0.6162724  699.5173 1         0.01288432
# 4   Bünktchen            pseudoword 0.5853792  760.5160 1        -0.01800880
# 5   Cermelen             pseudoword 0.5477454  767.1912 1        -0.05564265
# 6   Drücker              word       0.5730488  598.8304 1        -0.03033925
# 7   Durchszelten         pseudoword 0.5671816 2087.9393 1        -0.03620647
# 8   Erwachsener          word       0.6809480  636.2265 1         0.07755998
# 9   Exorzisten           word       0.6235078  744.7074 1         0.02011979
# 10  Exzingsener          pseudoword 0.5324633  922.2742 1        -0.07092476
# 11  Fabel                word       0.6343845  641.4402 1         0.03099644
# 12  Faulpelze            word       0.5894609  602.9854 1        -0.01392714
# 13  Figuren              word       0.7301291  525.4853 1         0.12674103
# 14  Filigrane            word       0.6749975  970.5680 1         0.07160946
# 15  Gamäse               pseudoword 0.5696685  606.4601 1        -0.03371957
# 16  Geschicke            word       0.4512565  717.0423 1        -0.15213153
# 17  Gisiblase            pseudoword 0.5315044  602.8824 1        -0.07188368
# 18  Gondel               word       0.6947889  697.9093 1         0.09140090
# 19  Gowuren              pseudoword 0.5398612  668.4597 1        -0.06352678
# 20  Grabens              word       0.7030543  633.8906 1         0.09966627
# 21  Hahnzusachen         pseudoword 0.4805572 1377.2252 1        -0.12283086
# 22  Hasteln              pseudoword 0.5570527  873.3611 1        -0.04633534
# 23  Horke                pseudoword 0.5920526  660.4095 1        -0.01133546
# 24  Jespelanges          pseudoword 0.5640034  724.1812 1        -0.03938466
# 25  Jugendfreund         word       0.6942410  607.3293 1         0.09085295
# 26  Kahästle             pseudoword 0.5502094  567.0308 1        -0.05317862
# 27  Kanaille             word       0.6233634  917.6175 1         0.01997535
# 28  Kanäle               word       0.7313112  575.7610 1         0.12792316
# 29  Klauchrertig         pseudoword 0.5380428  850.0500 1        -0.06534519
# 30  Knolto               pseudoword 0.5444923  827.3834 1        -0.05889578
# ... ...                  ...        ...       ...       ...      ...
# 271 verzieren            word       0.7263222  757.5855 1         0.1229341398
# 272 vezönlerten          pseudoword 0.5251437  646.5997 1        -0.0782443632
# 273 vorschrenntgadrig    pseudoword 0.5339742  897.2367 1        -0.0694138159
# 274 vorschriftswidrig    word       0.6031698 1074.7448 1        -0.0002182593
# 275 wafspiges            pseudoword 0.6185039  636.1758 1         0.0151158701
# 276 wahnsinnig           word       0.8447705  649.1393 1         0.2413824211
# 277 wegkomme             word       0.6856961  618.5577 1         0.0823081146
# 278 werillen             pseudoword 0.4399825  663.2418 1        -0.1634055664
# 279 weutamme             pseudoword 0.4449381  734.6730 1        -0.1584499707
# 280 wissenschaftlicheren word       0.7608551  757.7554 1         0.1574670921
# 281 wondrinnig           pseudoword 0.4723154  664.1183 1        -0.1310726334
# 282 wunderbaren          word       0.8764615  572.3919 1         0.2730734239
# 283 wundersamer          word       0.6839779  626.9146 1         0.0805898200
# 284 wunderschöne         word       0.8831501  622.3625 1         0.2797620426
# 285 zackiger             word       0.6673189  744.7399 1         0.0639308940
# 286 zatz                 pseudoword 0.4191390  622.6636 1        -0.1842490603
# 287 zeggt                pseudoword 0.5036876  617.8485 1        -0.0997004439
# 288 zerfanken            pseudoword 0.5328117  777.2366 1        -0.0705763091
# 289 zerrinnen            word       0.6125055 1007.1192 1         0.0091174970
# 290 zeugt                word       0.6530934  520.3588 1         0.0497053395
# 291 zuflüstern           word       0.7208457  742.6786 1         0.1174577008
# 292 zunandsgewägen       pseudoword 0.3937071 1179.9445 1        -0.2096809079
# 293 zurechtgebogen       word       0.6257972 1018.8596 1         0.0224091898
# 294 zurichgeschrafst     pseudoword 0.4287635 1068.3387 1        -0.1746245434
# 295 zurückgeschreckt     word       0.6647302  979.5155 1         0.0613421212
# 296 zürgiger             pseudoword 0.6080680  820.4015 1         0.0046799908
# 297 überbelegt           word       0.6246822  825.6721 1         0.0212941776
# 298 überlebensgroße      word       0.7568407  692.0386 1         0.1534527074
# 299 überlefätsglave      pseudoword 0.6315054  641.2879 1         0.0281173597
# 300 überlisten           word       0.6474396  705.1275 1         0.0440515528
#     dum_lex dev_lex
# 1   0       -0.5
# 2   1        0.5
# 3   0       -0.5
# 4   0       -0.5
# 5   0       -0.5
# 6   1        0.5
# 7   0       -0.5
# 8   1        0.5
# 9   1        0.5
# 10  0       -0.5
# 11  1        0.5
# 12  1        0.5
# 13  1        0.5
# 14  1        0.5
# 15  0       -0.5
# 16  1        0.5
# 17  0       -0.5
# 18  1        0.5
# 19  0       -0.5
# 20  1        0.5
# 21  0       -0.5
# 22  0       -0.5
# 23  0       -0.5
# 24  0       -0.5
# 25  1        0.5
# 26  0       -0.5
# 27  1        0.5
# 28  1        0.5
# 29  0       -0.5
# 30  0       -0.5
# ... ...     ...
# 271 1        0.5
# 272 0       -0.5
# 273 0       -0.5
# 274 1        0.5
# 275 0       -0.5
# 276 1        0.5
# 277 1        0.5
# 278 0       -0.5
# 279 0       -0.5
# 280 1        0.5
# 281 0       -0.5
# 282 1        0.5
# 283 1        0.5
# 284 1        0.5
# 285 1        0.5
# 286 0       -0.5
# 287 0       -0.5
# 288 0       -0.5
# 289 1        0.5
# 290 1        0.5
# 291 1        0.5
# 292 0       -0.5
# 293 1        0.5
# 294 0       -0.5
# 295 1        0.5
# 296 0       -0.5
# 297 1        0.5
# 298 1        0.5
# 299 0       -0.5
# 300 1        0.5

# %%
stim_averages |> print()
# Out:
# # A tibble: 300 x 8
#    text         condition    snd median_rt mean_acc snd_cent dum_lex dev_lex
#    <chr>        <chr>      <dbl>     <dbl>    <dbl>    <dbl>   <dbl>   <dbl>
#  1 Abgegöbe     pseudoword 0.614      942.        1   0.0104       0    -0.5
#  2 Akzente      word       0.716      628.        1   0.113        1     0.5
#  3 Austerbafer  pseudoword 0.616      700.        1   0.0129       0    -0.5
#  4 Bünktchen    pseudoword 0.585      761.        1  -0.0180       0    -0.5
#  5 Cermelen     pseudoword 0.548      767.        1  -0.0556       0    -0.5
#  6 Drücker      word       0.573      599.        1  -0.0303       1     0.5
#  7 Durchszelten pseudoword 0.567     2088.        1  -0.0362       0    -0.5
#  8 Erwachsener  word       0.681      636.        1   0.0776       1     0.5
#  9 Exorzisten   word       0.624      745.        1   0.0201       1     0.5
# 10 Exzingsener  pseudoword 0.532      922.        1  -0.0709       0    -0.5
# # i 290 more rows

# %% [markdown]
# ## 3: Estimate the Lexicality × SND Interaction
#
# Here we fit the model. Note that, unlike with frequency, it's up to you to interpret this one!

# %%
main_mod <- lm(median_rt ~ dev_lex * snd_cent, data = stim_averages)

summary(main_mod)
# Out:
# Call:
# lm(formula = median_rt ~ dev_lex * snd_cent, data = stim_averages)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -311.88 -135.11  -57.73   65.41 1909.51
#
# Coefficients:
#                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)        800.53      21.98  36.414  < 2e-16 ***
# dev_lex           -178.73      43.97  -4.065 6.16e-05 ***
# snd_cent            33.55     221.68   0.151   0.8798
# dev_lex:snd_cent  -792.94     443.35  -1.789   0.0747 .
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 236.5 on 296 degrees of freedom
# Multiple R-squared:  0.1284,	Adjusted R-squared:  0.1196
# F-statistic: 14.53 on 3 and 296 DF,  p-value: 7.421e-09

# %% [markdown]
# Finally, here is a plot showing the effect of SND for each lexicality condition.

# %%
stim_averages |>
  ggplot(aes(snd, median_rt, colour=condition)) +
  geom_point(alpha = 0.33) +  # alpha sets point transparency
  geom_smooth(method = "lm", formula = y ~ x) +
  labs(
    x = "Semantic Neighbourhood Diversity",
    y = "Median Response Time (ms)",
    colour = "Lexicality"
  )
# Out:
# plot without title
