# %% [markdown]
# # Analysis

# %% [markdown]
# The main thing we'll go through today is analysis of the Demo Experiment data. We have data from 8 participants who completed the experiment.
#
# **Before we can start:**
#
# **a**) [Download the demographics data](demo_demog.csv) as a `.csv` file, and place it in a directory that makes sense for you (e.g., called "demo_analysis").
#
# **b**) [Download the stimuli](demo_stimuli.csv) as a `.csv` file, and place it in the same demo analysis folder.
#
# **c**) [Download the raw trials data](demo_data.zip) as a `.zip` file.
#
# **d**) Extract the `data` folder from the `.zip` file and put it in your demo analysis folder.
#
# **e**) Start a new R script in RStudio, and save the `.R` file to the demo analysis folder.
#
# After following these instructions, you should have a directory structure that looks something like this:
#
# ```
# demo_analysis
# ├─ data
# │  ├─ trials_p171220.csv
# │  ├─ trials_p203530.csv
# │  └─ ...
# ├─ analysis.R
# └─ demo_demog.csv
# └─ demo_stimuli.csv
# ```
#
# Once everyone has completed these steps, we'll begin...

# %% [markdown]
# ## Loading the Data

# %% [markdown]
# #### 1: Load the Relevant Libraries
#
# These are the libraries we'll use for the analysis. Each library has a comment explaining what we will use it for.

# %%
options(repr.plot.width=3.5, repr.plot.height=3)
library(ggplot2)
theme_set(theme_classic() + theme(legend.position="top"))

# %%
library(readr)    # for reading the data into R
library(purrr)    # for easily importing multiple files
library(dplyr)    # for wrangling data (e.g., adding/renaming columns)

library(ggplot2)  # for visualising data
# Out:
# Attaching package: 'dplyr'
#
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union

# %% [markdown]
# #### 2. Import the Demographic Data
#
# First, we import the demographics data. This gives us some details about the participants who took part.

# %%
demog <- read_csv("demo_demog.csv")
# Out:
# Rows: 17 Columns: 7
# -- Column specification ------------------------------------------------------------
# Delimiter: ","
# chr (4): participant_id, gender, dominant_hand, first_language
# dbl (3): age, frame_rate_Hz, total_time_secs
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %% [markdown]
# This will print some details about the columns imported. Let's have a look at the data we imported. We have some missing data, but enough information to report age and gender information.

# %%
demog
# Out:
#    participant_id age gender dominant_hand first_language frame_rate_Hz
# 1  p015270        21  male   right         german          59.63712
# 2  p063288        20  female right         german          60.12774
# 3  p072235        34  male   right         german         118.65868
# 4  p110412        24  female right         german                NA
# 5  p153023        21  female right         german          59.25592
# 6  p241074        22  female right         german          60.11102
# 7  p255886        22  female right         german          60.09839
# 8  p389724        20  female right         german          60.01173
# 9  p445631        21  female right         german                NA
# 10 p506691        21  female left          german          60.00888
# 11 p532670        22  female right         german          59.93810
# 12 p539652        22  male   right         german                NA
# 13 p551117        21  female right         german          59.95683
# 14 p555715        21  female right         german          60.13840
# 15 p596865        19  female right         german         118.78701
# 16 p697533        25  female right         german          59.98217
# 17 p813475        22  female right         german         117.01946
#    total_time_secs
# 1   603.7979
# 2   679.4045
# 3   541.8548
# 4   589.8353
# 5   866.3454
# 6   692.1515
# 7   796.0341
# 8   648.9699
# 9   743.3470
# 10  731.5087
# 11  682.9029
# 12  734.8969
# 13  784.0845
# 14 5887.0749
# 15  693.2907
# 16  691.3681
# 17  662.1397

# %%
demog |> print()
# Out:
# # A tibble: 17 x 7
#    participant_id   age gender dominant_hand first_language frame_rate_Hz
#    <chr>          <dbl> <chr>  <chr>         <chr>                  <dbl>
#  1 p015270           21 male   right         german                  59.6
#  2 p063288           20 female right         german                  60.1
#  3 p072235           34 male   right         german                 119.
#  4 p110412           24 female right         german                  NA
#  5 p153023           21 female right         german                  59.3
#  6 p241074           22 female right         german                  60.1
#  7 p255886           22 female right         german                  60.1
#  8 p389724           20 female right         german                  60.0
#  9 p445631           21 female right         german                  NA
# 10 p506691           21 female left          german                  60.0
# 11 p532670           22 female right         german                  59.9
# 12 p539652           22 male   right         german                  NA
# 13 p551117           21 female right         german                  60.0
# 14 p555715           21 female right         german                  60.1
# 15 p596865           19 female right         german                 119.
# 16 p697533           25 female right         german                  60.0
# 17 p813475           22 female right         german                 117.
# # i 1 more variable: total_time_secs <dbl>

# %% [markdown]
# #### 3: Import the Stimuli
#
# Next we import the list of stimuli:

# %%
stim <- read_csv("demo_stimuli.csv")

stim
# Out:
# Rows: 300 Columns: 8
# -- Column specification ------------------------------------------------------------
# Delimiter: ","
# chr (3): condition, text, corr_ans
# dbl (4): item_nr, snd, ZipfSUBTLEX, word_len
# lgl (1): is_practice_trial
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
#     item_nr condition  text                 corr_ans is_practice_trial
# 1    1      word       Akzente              ralt     FALSE
# 2    1      pseudoword Unwante              lalt     FALSE
# 3    2      word       Drücker              ralt     FALSE
# 4    2      pseudoword quokker              lalt     FALSE
# 5    3      word       Erwachsener          ralt     FALSE
# 6    3      pseudoword Exzingsener          lalt     FALSE
# 7    4      word       Exorzisten           ralt     FALSE
# 8    4      pseudoword ucinzisten           lalt     FALSE
# 9    5      word       Fabel                ralt     FALSE
# 10   5      pseudoword Pafel                lalt     FALSE
# 11   6      word       Faulpelze            ralt     FALSE
# 12   6      pseudoword peigpelze            lalt     FALSE
# 13   7      word       Figuren              ralt     FALSE
# 14   7      pseudoword Gowuren              lalt     FALSE
# 15   8      word       Filigrane            ralt     FALSE
# 16   8      pseudoword Gisiblase            lalt     FALSE
# 17   9      word       Geschicke            ralt     FALSE
# 18   9      pseudoword neschonke            lalt     FALSE
# 19  10      word       Gondel               ralt     FALSE
# 20  10      pseudoword pändel               lalt     FALSE
# 21  11      word       Grabens              ralt     FALSE
# 22  11      pseudoword Phabert              lalt     FALSE
# 23  12      word       Jugendfreund         ralt     FALSE
# 24  12      pseudoword Kugendfrophs         lalt     FALSE
# 25  13      word       Kanaille             ralt     FALSE
# 26  13      pseudoword Kahästle             lalt     FALSE
# 27  14      word       Kanäle               ralt     FALSE
# 28  14      pseudoword Gamäse               lalt     FALSE
# 29  15      word       Kollegium            ralt     FALSE
# 30  15      pseudoword Toffegizu            lalt     FALSE
# ... ...     ...        ...                  ...      ...
# 271 136     word       wahnsinnig           ralt     FALSE
# 272 136     pseudoword wondrinnig           lalt     FALSE
# 273 137     word       wegkomme             ralt     FALSE
# 274 137     pseudoword weutamme             lalt     FALSE
# 275 138     word       wissenschaftlicheren ralt     FALSE
# 276 138     pseudoword mempenschelllicheren lalt     FALSE
# 277 139     word       wunderbaren          ralt     FALSE
# 278 139     pseudoword Vuljerwagen          lalt     FALSE
# 279 140     word       wundersamer          ralt     FALSE
# 280 140     pseudoword Austerbafer          lalt     FALSE
# 281 141     word       wunderschöne         ralt     FALSE
# 282 141     pseudoword pulderstrüse         lalt     FALSE
# 283 142     word       zackiger             ralt     FALSE
# 284 142     pseudoword zürgiger             lalt     FALSE
# 285 143     word       zerrinnen            ralt     FALSE
# 286 143     pseudoword zerfanken            lalt     FALSE
# 287 144     word       zeugt                ralt     FALSE
# 288 144     pseudoword zeggt                lalt     FALSE
# 289 145     word       zuflüstern           ralt     FALSE
# 290 145     pseudoword umdröstern           lalt     FALSE
# 291 146     word       zurechtgebogen       ralt     FALSE
# 292 146     pseudoword zunandsgewägen       lalt     FALSE
# 293 147     word       zurückgeschreckt     ralt     FALSE
# 294 147     pseudoword zurichgeschrafst     lalt     FALSE
# 295 148     word       überbelegt           ralt     FALSE
# 296 148     pseudoword iberfenerb           lalt     FALSE
# 297 149     word       überlebensgroße      ralt     FALSE
# 298 149     pseudoword überlefätsglave      lalt     FALSE
# 299 150     word       überlisten           ralt     FALSE
# 300 150     pseudoword otertesten           lalt     FALSE
#     snd       ZipfSUBTLEX word_len
# 1   0.7164028 2.71         7
# 2   0.5337820   NA         7
# 3   0.5730488 3.01         7
# 4   0.5511313   NA         7
# 5   0.6809480 3.95        11
# 6   0.5324633   NA        11
# 7   0.6235078 2.64        10
# 8   0.4170587   NA        10
# 9   0.6343845 2.60         5
# 10  0.5519994   NA         5
# 11  0.5894609 2.74         9
# 12  0.5777983   NA         9
# 13  0.7301291 4.38         7
# 14  0.5398612   NA         7
# 15  0.6749975 1.90         9
# 16  0.5315044   NA         9
# 17  0.4512565 2.07         9
# 18  0.4765813   NA         9
# 19  0.6947889 3.11         6
# 20  0.4685015   NA         6
# 21  0.7030543 1.90         7
# 22  0.4602155   NA         7
# 23  0.6942410 2.55        12
# 24  0.4639937   NA        12
# 25  0.6233634 2.44         8
# 26  0.5502094   NA         8
# 27  0.7313112 3.59         6
# 28  0.5696685   NA         6
# 29  0.6807463 2.67         9
# 30  0.5886507   NA         9
# ... ...       ...         ...
# 271 0.8447705 4.55        10
# 272 0.4723154   NA        10
# 273 0.6856961 2.85         8
# 274 0.4449381   NA         8
# 275 0.7608551 2.07        20
# 276 0.4630420   NA        20
# 277 0.8764615 3.87        11
# 278 0.5847260   NA        11
# 279 0.6839779 2.29        11
# 280 0.6162724   NA        11
# 281 0.8831501 4.16        12
# 282 0.5515038   NA        12
# 283 0.6673189 2.20         8
# 284 0.6080680   NA         8
# 285 0.6125055 1.90         9
# 286 0.5328117   NA         9
# 287 0.6530934 3.30         5
# 288 0.5036876   NA         5
# 289 0.7208457 2.64        10
# 290 0.4849664   NA        10
# 291 0.6257972 2.07        14
# 292 0.3937071   NA        14
# 293 0.6647302 1.90        16
# 294 0.4287635   NA        16
# 295 0.6246822 2.20        10
# 296 0.4673373   NA        10
# 297 0.7568407 1.90        15
# 298 0.6315054   NA        15
# 299 0.6474396 3.33        10
# 300 0.6183059   NA        10

# %%
stim |> print()
# Out:
# # A tibble: 300 x 8
#    item_nr condition text  corr_ans is_practice_trial   snd ZipfSUBTLEX word_len
#      <dbl> <chr>     <chr> <chr>    <lgl>             <dbl>       <dbl>    <dbl>
#  1       1 word      Akze~ ralt     FALSE             0.716        2.71        7
#  2       1 pseudowo~ Unwa~ lalt     FALSE             0.534       NA           7
#  3       2 word      Drüc~ ralt     FALSE             0.573        3.01        7
#  4       2 pseudowo~ quok~ lalt     FALSE             0.551       NA           7
#  5       3 word      Erwa~ ralt     FALSE             0.681        3.95       11
#  6       3 pseudowo~ Exzi~ lalt     FALSE             0.532       NA          11
#  7       4 word      Exor~ ralt     FALSE             0.624        2.64       10
#  8       4 pseudowo~ ucin~ lalt     FALSE             0.417       NA          10
#  9       5 word      Fabel ralt     FALSE             0.634        2.6         5
# 10       5 pseudowo~ Pafel lalt     FALSE             0.552       NA           5
# # i 290 more rows

# %% [markdown]
# This has 8 columns:
#
# * `item_nr` - an ID for each matched pair of words and pseudowords
#
# * `condition` - whether each item is a `"word"` or `"pseudoword"`
#
# * `text` - the text shown to the participant
#
# * `corr_ans` - whether the correct answer was to press the left alt key (`"lalt"`) or the right alt key (`"ralt"`)
#
# * `snd` - semantic neighbourhood density, calculated using the fastText model, using the method described by Hendrix & Sun ([2020](https://doi.org/10.1037/xlm0000819))
#
# * `ZipfSUBTLEX` - a measure of word frequency from a german subtitle corpus: SUBTLEX-DE (Bysbaert et al., [2011](https://doi.org/10.1027/1618-3169/a000123)). For more info on the "Zipf" measure, see Brysbaert et al. ([2017](
# https://doi.org/10.1177/096372141772752))
#
# * `word_len` - number of letters in the word / pseudoword

# %% [markdown]
# #### 4: Import the Raw Data
#
# Let's import the experiment data from the `data` folder:

# %%
# first, get a list of all .csv data files
data_paths <- list.files("data", pattern=".*\\.csv$", full.names=TRUE)

# now, iterate over these with `read_csv()` to import each
raw_data <- map_df(data_paths, read_csv)

# print the contents
raw_data
# Out:
# Rows: 310 Columns: 8
# -- Column specification ------------------------------------------------------------
# Delimiter: ","
# chr (4): participant_id, condition, text, resp
# dbl (3): item_nr, rt_ms, time_so_far_secs
# lgl (1): is_practice_trial
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 310 Columns: 8
# -- Column specification ------------------------------------------------------------
# Delimiter: ","
# chr (4): participant_id, condition, text, resp
# dbl (3): item_nr, rt_ms, time_so_far_secs
# lgl (1): is_practice_trial
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 310 Columns: 8
# -- Column specification ------------------------------------------------------------
# Delimiter: ","
# chr (4): participant_id, condition, text, resp
# dbl (3): item_nr, rt_ms, time_so_far_secs
# lgl (1): is_practice_trial
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 310 Columns: 8
# -- Column specification ------------------------------------------------------------
# Delimiter: ","
# chr (4): participant_id, condition, text, resp
# dbl (3): item_nr, rt_ms, time_so_far_secs
# lgl (1): is_practice_trial
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 310 Columns: 8
# -- Column specification ------------------------------------------------------------
# Delimiter: ","
# chr (4): participant_id, condition, text, resp
# dbl (3): item_nr, rt_ms, time_so_far_secs
# lgl (1): is_practice_trial
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 310 Columns: 8
# -- Column specification ------------------------------------------------------------
# Delimiter: ","
# chr (4): participant_id, condition, text, resp
# dbl (3): item_nr, rt_ms, time_so_far_secs
# lgl (1): is_practice_trial
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 310 Columns: 8
# -- Column specification ------------------------------------------------------------
# Delimiter: ","
# chr (4): participant_id, condition, text, resp
# dbl (3): item_nr, rt_ms, time_so_far_secs
# lgl (1): is_practice_trial
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 310 Columns: 8
# -- Column specification ------------------------------------------------------------
# Delimiter: ","
# chr (4): participant_id, condition, text, resp
# dbl (3): item_nr, rt_ms, time_so_far_secs
# lgl (1): is_practice_trial
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 310 Columns: 8
# -- Column specification ------------------------------------------------------------
# Delimiter: ","
# chr (4): participant_id, condition, text, resp
# dbl (3): item_nr, rt_ms, time_so_far_secs
# lgl (1): is_practice_trial
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 310 Columns: 8
# -- Column specification ------------------------------------------------------------
# Delimiter: ","
# chr (4): participant_id, condition, text, resp
# dbl (3): item_nr, rt_ms, time_so_far_secs
# lgl (1): is_practice_trial
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 310 Columns: 8
# -- Column specification ------------------------------------------------------------
# Delimiter: ","
# chr (4): participant_id, condition, text, resp
# dbl (3): item_nr, rt_ms, time_so_far_secs
# lgl (1): is_practice_trial
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 310 Columns: 8
# -- Column specification ------------------------------------------------------------
# Delimiter: ","
# chr (4): participant_id, condition, text, resp
# dbl (3): item_nr, rt_ms, time_so_far_secs
# lgl (1): is_practice_trial
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 310 Columns: 8
# -- Column specification ------------------------------------------------------------
# Delimiter: ","
# chr (4): participant_id, condition, text, resp
# dbl (3): item_nr, rt_ms, time_so_far_secs
# lgl (1): is_practice_trial
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 310 Columns: 8
# -- Column specification ------------------------------------------------------------
# Delimiter: ","
# chr (4): participant_id, condition, text, resp
# dbl (3): item_nr, rt_ms, time_so_far_secs
# lgl (1): is_practice_trial
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 310 Columns: 8
# -- Column specification ------------------------------------------------------------
# Delimiter: ","
# chr (4): participant_id, condition, text, resp
# dbl (3): item_nr, rt_ms, time_so_far_secs
# lgl (1): is_practice_trial
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 310 Columns: 8
# -- Column specification ------------------------------------------------------------
# Delimiter: ","
# chr (4): participant_id, condition, text, resp
# dbl (3): item_nr, rt_ms, time_so_far_secs
# lgl (1): is_practice_trial
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 310 Columns: 8
# -- Column specification ------------------------------------------------------------
# Delimiter: ","
# chr (4): participant_id, condition, text, resp
# dbl (3): item_nr, rt_ms, time_so_far_secs
# lgl (1): is_practice_trial
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
#      participant_id item_nr condition  text                 is_practice_trial
# 1    p015270          3     pseudoword Torrerk               TRUE
# 2    p015270          3     word       korrekt               TRUE
# 3    p015270          5     pseudoword tobreren              TRUE
# 4    p015270          2     word       Mannes                TRUE
# 5    p015270          4     word       sagt                  TRUE
# 6    p015270          1     word       Haie                  TRUE
# 7    p015270          4     pseudoword segt                  TRUE
# 8    p015270          2     pseudoword sanzes                TRUE
# 9    p015270          5     word       sicheren              TRUE
# 10   p015270          1     pseudoword Bage                  TRUE
# 11   p015270         81     pseudoword emptöltig            FALSE
# 12   p015270        114     word       rasselt              FALSE
# 13   p015270         68     word       baufälliges          FALSE
# 14   p015270        146     pseudoword zunandsgewägen       FALSE
# 15   p015270        103     pseudoword lenmalimieren        FALSE
# 16   p015270         86     word       erziehst             FALSE
# 17   p015270         90     pseudoword riviert              FALSE
# 18   p015270        105     pseudoword seteinagelesenischem FALSE
# 19   p015270         69     word       befolgen             FALSE
# 20   p015270        150     pseudoword otertesten           FALSE
# 21   p015270         82     pseudoword itzgegerfonwende     FALSE
# 22   p015270         13     pseudoword Kahästle             FALSE
# 23   p015270        102     pseudoword Sauste               FALSE
# 24   p015270          5     word       Fabel                FALSE
# 25   p015270        106     word       lebenslänglich       FALSE
# 26   p015270          7     pseudoword Gowuren              FALSE
# 27   p015270         92     pseudoword räntere              FALSE
# 28   p015270        108     pseudoword fitzten              FALSE
# 29   p015270         43     pseudoword Abgegöbe             FALSE
# 30   p015270        122     word       spuckten             FALSE
# ...  ...            ...     ...        ...                  ...
# 5241 p813475          3     word       Erwachsener          FALSE
# 5242 p813475        133     word       verzeichnet          FALSE
# 5243 p813475          2     pseudoword quokker              FALSE
# 5244 p813475         11     pseudoword Phabert              FALSE
# 5245 p813475         16     pseudoword Rabphimution         FALSE
# 5246 p813475        126     word       undurchdringbar      FALSE
# 5247 p813475        121     pseudoword sopfeibt             FALSE
# 5248 p813475         45     word       Vertragsabschlüssen  FALSE
# 5249 p813475         33     word       Skonto               FALSE
# 5250 p813475         70     pseudoword vezönlerten          FALSE
# 5251 p813475        147     word       zurückgeschreckt     FALSE
# 5252 p813475         33     pseudoword Knolto               FALSE
# 5253 p813475         95     pseudoword peschüchen           FALSE
# 5254 p813475         98     pseudoword horfege              FALSE
# 5255 p813475         76     word       doch                 FALSE
# 5256 p813475         87     word       ferneren             FALSE
# 5257 p813475         26     word       Parzellen            FALSE
# 5258 p813475         35     pseudoword fopfeträrger         FALSE
# 5259 p813475        125     word       telepathischen       FALSE
# 5260 p813475        134     pseudoword verkauben            FALSE
# 5261 p813475         10     pseudoword pändel               FALSE
# 5262 p813475         66     pseudoword aufnendöl            FALSE
# 5263 p813475        114     pseudoword messelt              FALSE
# 5264 p813475          7     word       Figuren              FALSE
# 5265 p813475        122     pseudoword Spruntet             FALSE
# 5266 p813475         57     pseudoword abbeßen              FALSE
# 5267 p813475        124     pseudoword nippakrisierst       FALSE
# 5268 p813475         18     word       Kreuzzug             FALSE
# 5269 p813475        142     word       zackiger             FALSE
# 5270 p813475         92     word       füttere              FALSE
#      resp rt_ms     time_so_far_secs
# 1    ralt  949.2878 22.97152
# 2    ralt  713.7811 25.45998
# 3    lalt 1017.4027 27.72446
# 4    lalt  629.6885 30.29657
# 5    lalt  710.9209 32.47331
# 6    ralt  904.9975 34.73792
# 7    lalt 1308.3576 37.20362
# 8    lalt  642.6694 40.07643
# 9    ralt  703.0854 42.27066
# 10   lalt  761.9219 44.53942
# 11   lalt 1590.0806 49.38928
# 12   lalt 1128.3351 51.96809
# 13   ralt  895.4652 54.12166
# 14   lalt 1060.6754 56.03406
# 15   lalt 1041.4273 58.11564
# 16   ralt  520.4048 60.18089
# 17   lalt  795.5358 61.73011
# 18   lalt  637.6826 63.54714
# 19   ralt  564.1812 65.21182
# 20   lalt  662.1214 66.81157
# 21   lalt  596.3621 68.47907
# 22   lalt  590.1206 70.09419
# 23   lalt  539.3837 71.70899
# 24   ralt  691.4518 73.27477
# 25   ralt  568.7857 74.99301
# 26   lalt  652.9424 76.59005
# 27   lalt  762.6170 78.27255
# 28   ralt  520.5668 80.05560
# 29   lalt  955.9861 81.60552
# 30   ralt  551.8347 83.58683
# ...  ...  ...       ...
# 5241 ralt  509.7735 614.2522
# 5242 ralt  445.5466 615.7737
# 5243 lalt  491.1520 617.2233
# 5244 lalt  721.7861 618.7248
# 5245 lalt  544.9173 620.4428
# 5246 ralt  636.7679 621.9971
# 5247 lalt  566.5274 623.6366
# 5248 ralt  637.1488 625.2067
# 5249 lalt  508.5127 626.8470
# 5250 lalt  540.0505 628.3566
# 5251 ralt 1265.3308 629.8968
# 5252 lalt  611.6073 632.1622
# 5253 lalt  586.6359 633.7811
# 5254 lalt  434.8833 635.3673
# 5255 ralt  533.4705 636.8125
# 5256 lalt  534.7717 638.3546
# 5257 ralt  583.5780 639.8950
# 5258 lalt  819.1523 641.4840
# 5259 ralt  881.5467 643.3120
# 5260 lalt  795.1544 645.1917
# 5261 lalt 1013.9573 646.9934
# 5262 lalt  592.5678 649.0073
# 5263 lalt  800.4310 650.6022
# 5264 ralt  525.3252 652.4019
# 5265 lalt  616.2731 653.9347
# 5266 lalt  732.0032 655.5575
# 5267 lalt  567.2824 657.2926
# 5268 ralt  641.6553 658.8729
# 5269 ralt  616.4613 660.5181
# 5270 ralt  543.3666 662.1397

# %%
raw_data |> print()
# Out:
# # A tibble: 5,270 x 8
#    participant_id item_nr condition  text     is_practice_trial resp  rt_ms
#    <chr>            <dbl> <chr>      <chr>    <lgl>             <chr> <dbl>
#  1 p015270              3 pseudoword Torrerk  TRUE              ralt   949.
#  2 p015270              3 word       korrekt  TRUE              ralt   714.
#  3 p015270              5 pseudoword tobreren TRUE              lalt  1017.
#  4 p015270              2 word       Mannes   TRUE              lalt   630.
#  5 p015270              4 word       sagt     TRUE              lalt   711.
#  6 p015270              1 word       Haie     TRUE              ralt   905.
#  7 p015270              4 pseudoword segt     TRUE              lalt  1308.
#  8 p015270              2 pseudoword sanzes   TRUE              lalt   643.
#  9 p015270              5 word       sicheren TRUE              ralt   703.
# 10 p015270              1 pseudoword Bage     TRUE              lalt   762.
# # i 5,260 more rows
# # i 1 more variable: time_so_far_secs <dbl>

# %% [markdown]
# This gives us one data frame with all trials in the experiment.
#
# There are 8 columns of data:
#
# * `participant_id` - a unique ID for each paricipant
#
# * `item_nr`- the same item ID as in `stim`
#
# * `condition` - whether the trial showed a `"word"` or `"pseudoword"`
#
# * `text` - the text that the participant saw
#
# * `is_practice_trial` - whether each trial was a practice trial. The first 10 trials for each participant will be practice trials.
#
# * `resp` - left alt key (`"lalt"`) or the right alt key (`"ralt"`)
#
# * `rt_ms` - the response time in milliseconds
#
# * `time_so_far_secs`  - amount of time, in seconds, that has passed from the start of the experiment

# %% [markdown]
# #### 5: Join the Data Together
#
# The easiest way to work with small datasets like this is to just join the dataframes together. This will create some redundancy (e.g., participant ages will be repeated 300 times), but can make things easier to work with.
#
# Here we use `left_join()` to find add information about participant demographics and features of the stimuli. This identifies columns that the dataframes have in common, and joins them togeher. Notice that we now have one big dataframe with all of the information about every trial.

# %%
all_dat <- raw_data |>
  left_join(demog) |>
  left_join(stim)
# Out:
# Joining with `by = join_by(participant_id)`
# Joining with `by = join_by(item_nr, condition, text, is_practice_trial)`

# %%
all_dat
# Out:
#      participant_id item_nr condition  text                 is_practice_trial
# 1    p015270          3     pseudoword Torrerk               TRUE
# 2    p015270          3     word       korrekt               TRUE
# 3    p015270          5     pseudoword tobreren              TRUE
# 4    p015270          2     word       Mannes                TRUE
# 5    p015270          4     word       sagt                  TRUE
# 6    p015270          1     word       Haie                  TRUE
# 7    p015270          4     pseudoword segt                  TRUE
# 8    p015270          2     pseudoword sanzes                TRUE
# 9    p015270          5     word       sicheren              TRUE
# 10   p015270          1     pseudoword Bage                  TRUE
# 11   p015270         81     pseudoword emptöltig            FALSE
# 12   p015270        114     word       rasselt              FALSE
# 13   p015270         68     word       baufälliges          FALSE
# 14   p015270        146     pseudoword zunandsgewägen       FALSE
# 15   p015270        103     pseudoword lenmalimieren        FALSE
# 16   p015270         86     word       erziehst             FALSE
# 17   p015270         90     pseudoword riviert              FALSE
# 18   p015270        105     pseudoword seteinagelesenischem FALSE
# 19   p015270         69     word       befolgen             FALSE
# 20   p015270        150     pseudoword otertesten           FALSE
# 21   p015270         82     pseudoword itzgegerfonwende     FALSE
# 22   p015270         13     pseudoword Kahästle             FALSE
# 23   p015270        102     pseudoword Sauste               FALSE
# 24   p015270          5     word       Fabel                FALSE
# 25   p015270        106     word       lebenslänglich       FALSE
# 26   p015270          7     pseudoword Gowuren              FALSE
# 27   p015270         92     pseudoword räntere              FALSE
# 28   p015270        108     pseudoword fitzten              FALSE
# 29   p015270         43     pseudoword Abgegöbe             FALSE
# 30   p015270        122     word       spuckten             FALSE
# ...  ...            ...     ...        ...                  ...
# 5241 p813475          3     word       Erwachsener          FALSE
# 5242 p813475        133     word       verzeichnet          FALSE
# 5243 p813475          2     pseudoword quokker              FALSE
# 5244 p813475         11     pseudoword Phabert              FALSE
# 5245 p813475         16     pseudoword Rabphimution         FALSE
# 5246 p813475        126     word       undurchdringbar      FALSE
# 5247 p813475        121     pseudoword sopfeibt             FALSE
# 5248 p813475         45     word       Vertragsabschlüssen  FALSE
# 5249 p813475         33     word       Skonto               FALSE
# 5250 p813475         70     pseudoword vezönlerten          FALSE
# 5251 p813475        147     word       zurückgeschreckt     FALSE
# 5252 p813475         33     pseudoword Knolto               FALSE
# 5253 p813475         95     pseudoword peschüchen           FALSE
# 5254 p813475         98     pseudoword horfege              FALSE
# 5255 p813475         76     word       doch                 FALSE
# 5256 p813475         87     word       ferneren             FALSE
# 5257 p813475         26     word       Parzellen            FALSE
# 5258 p813475         35     pseudoword fopfeträrger         FALSE
# 5259 p813475        125     word       telepathischen       FALSE
# 5260 p813475        134     pseudoword verkauben            FALSE
# 5261 p813475         10     pseudoword pändel               FALSE
# 5262 p813475         66     pseudoword aufnendöl            FALSE
# 5263 p813475        114     pseudoword messelt              FALSE
# 5264 p813475          7     word       Figuren              FALSE
# 5265 p813475        122     pseudoword Spruntet             FALSE
# 5266 p813475         57     pseudoword abbeßen              FALSE
# 5267 p813475        124     pseudoword nippakrisierst       FALSE
# 5268 p813475         18     word       Kreuzzug             FALSE
# 5269 p813475        142     word       zackiger             FALSE
# 5270 p813475         92     word       füttere              FALSE
#      resp rt_ms     time_so_far_secs age gender dominant_hand first_language
# 1    ralt  949.2878 22.97152         21  male   right         german
# 2    ralt  713.7811 25.45998         21  male   right         german
# 3    lalt 1017.4027 27.72446         21  male   right         german
# 4    lalt  629.6885 30.29657         21  male   right         german
# 5    lalt  710.9209 32.47331         21  male   right         german
# 6    ralt  904.9975 34.73792         21  male   right         german
# 7    lalt 1308.3576 37.20362         21  male   right         german
# 8    lalt  642.6694 40.07643         21  male   right         german
# 9    ralt  703.0854 42.27066         21  male   right         german
# 10   lalt  761.9219 44.53942         21  male   right         german
# 11   lalt 1590.0806 49.38928         21  male   right         german
# 12   lalt 1128.3351 51.96809         21  male   right         german
# 13   ralt  895.4652 54.12166         21  male   right         german
# 14   lalt 1060.6754 56.03406         21  male   right         german
# 15   lalt 1041.4273 58.11564         21  male   right         german
# 16   ralt  520.4048 60.18089         21  male   right         german
# 17   lalt  795.5358 61.73011         21  male   right         german
# 18   lalt  637.6826 63.54714         21  male   right         german
# 19   ralt  564.1812 65.21182         21  male   right         german
# 20   lalt  662.1214 66.81157         21  male   right         german
# 21   lalt  596.3621 68.47907         21  male   right         german
# 22   lalt  590.1206 70.09419         21  male   right         german
# 23   lalt  539.3837 71.70899         21  male   right         german
# 24   ralt  691.4518 73.27477         21  male   right         german
# 25   ralt  568.7857 74.99301         21  male   right         german
# 26   lalt  652.9424 76.59005         21  male   right         german
# 27   lalt  762.6170 78.27255         21  male   right         german
# 28   ralt  520.5668 80.05560         21  male   right         german
# 29   lalt  955.9861 81.60552         21  male   right         german
# 30   ralt  551.8347 83.58683         21  male   right         german
# ...  ...  ...       ...              ... ...    ...           ...
# 5241 ralt  509.7735 614.2522         22  female right         german
# 5242 ralt  445.5466 615.7737         22  female right         german
# 5243 lalt  491.1520 617.2233         22  female right         german
# 5244 lalt  721.7861 618.7248         22  female right         german
# 5245 lalt  544.9173 620.4428         22  female right         german
# 5246 ralt  636.7679 621.9971         22  female right         german
# 5247 lalt  566.5274 623.6366         22  female right         german
# 5248 ralt  637.1488 625.2067         22  female right         german
# 5249 lalt  508.5127 626.8470         22  female right         german
# 5250 lalt  540.0505 628.3566         22  female right         german
# 5251 ralt 1265.3308 629.8968         22  female right         german
# 5252 lalt  611.6073 632.1622         22  female right         german
# 5253 lalt  586.6359 633.7811         22  female right         german
# 5254 lalt  434.8833 635.3673         22  female right         german
# 5255 ralt  533.4705 636.8125         22  female right         german
# 5256 lalt  534.7717 638.3546         22  female right         german
# 5257 ralt  583.5780 639.8950         22  female right         german
# 5258 lalt  819.1523 641.4840         22  female right         german
# 5259 ralt  881.5467 643.3120         22  female right         german
# 5260 lalt  795.1544 645.1917         22  female right         german
# 5261 lalt 1013.9573 646.9934         22  female right         german
# 5262 lalt  592.5678 649.0073         22  female right         german
# 5263 lalt  800.4310 650.6022         22  female right         german
# 5264 ralt  525.3252 652.4019         22  female right         german
# 5265 lalt  616.2731 653.9347         22  female right         german
# 5266 lalt  732.0032 655.5575         22  female right         german
# 5267 lalt  567.2824 657.2926         22  female right         german
# 5268 ralt  641.6553 658.8729         22  female right         german
# 5269 ralt  616.4613 660.5181         22  female right         german
# 5270 ralt  543.3666 662.1397         22  female right         german
#      frame_rate_Hz total_time_secs corr_ans snd       ZipfSUBTLEX word_len
# 1    59.63712      603.7979        NA              NA   NA        NA
# 2    59.63712      603.7979        NA              NA   NA        NA
# 3    59.63712      603.7979        NA              NA   NA        NA
# 4    59.63712      603.7979        NA              NA   NA        NA
# 5    59.63712      603.7979        NA              NA   NA        NA
# 6    59.63712      603.7979        NA              NA   NA        NA
# 7    59.63712      603.7979        NA              NA   NA        NA
# 8    59.63712      603.7979        NA              NA   NA        NA
# 9    59.63712      603.7979        NA              NA   NA        NA
# 10   59.63712      603.7979        NA              NA   NA        NA
# 11   59.63712      603.7979        lalt     0.4592212   NA         9
# 12   59.63712      603.7979        ralt     0.6476749 2.20         7
# 13   59.63712      603.7979        ralt     0.7153390 2.29        11
# 14   59.63712      603.7979        lalt     0.3937071   NA        14
# 15   59.63712      603.7979        lalt     0.4515125   NA        13
# 16   59.63712      603.7979        ralt     0.6755329 2.20         8
# 17   59.63712      603.7979        lalt     0.5590397   NA         7
# 18   59.63712      603.7979        lalt     0.5348293   NA        20
# 19   59.63712      603.7979        ralt     0.7071671 4.00         8
# 20   59.63712      603.7979        lalt     0.6183059   NA        10
# 21   59.63712      603.7979        lalt     0.5084249   NA        16
# 22   59.63712      603.7979        lalt     0.5502094   NA         8
# 23   59.63712      603.7979        lalt     0.5445310   NA         6
# 24   59.63712      603.7979        ralt     0.6343845 2.60         5
# 25   59.63712      603.7979        ralt     0.6668413 3.77        14
# 26   59.63712      603.7979        lalt     0.5398612   NA         7
# 27   59.63712      603.7979        lalt     0.6225293   NA         7
# 28   59.63712      603.7979        lalt     0.5893931   NA         7
# 29   59.63712      603.7979        lalt     0.6138101   NA         8
# 30   59.63712      603.7979        ralt     0.6811973 2.44         8
# ...  ...           ...             ...      ...       ...         ...
# 5241 117.0195      662.1397        ralt     0.6809480 3.95        11
# 5242 117.0195      662.1397        ralt     0.7002903 3.19        11
# 5243 117.0195      662.1397        lalt     0.5511313   NA         7
# 5244 117.0195      662.1397        lalt     0.4602155   NA         7
# 5245 117.0195      662.1397        lalt     0.6490053   NA        12
# 5246 117.0195      662.1397        ralt     0.6526890 2.37        15
# 5247 117.0195      662.1397        lalt     0.5913555   NA         8
# 5248 117.0195      662.1397        ralt     0.6929057 1.90        19
# 5249 117.0195      662.1397        ralt     0.6775692 2.07         6
# 5250 117.0195      662.1397        lalt     0.5251437   NA        11
# 5251 117.0195      662.1397        ralt     0.6647302 1.90        16
# 5252 117.0195      662.1397        lalt     0.5444923   NA         6
# 5253 117.0195      662.1397        lalt     0.4850652   NA        10
# 5254 117.0195      662.1397        lalt     0.4307307   NA         7
# 5255 117.0195      662.1397        ralt     0.8115719 6.39         4
# 5256 117.0195      662.1397        ralt     0.6648234 1.90         8
# 5257 117.0195      662.1397        ralt     0.7221180 2.07         9
# 5258 117.0195      662.1397        lalt     0.5394920   NA        12
# 5259 117.0195      662.1397        ralt     0.7471151 2.29        14
# 5260 117.0195      662.1397        lalt     0.5819592   NA         9
# 5261 117.0195      662.1397        lalt     0.4685015   NA         6
# 5262 117.0195      662.1397        lalt     0.4656188   NA         9
# 5263 117.0195      662.1397        lalt     0.5852153   NA         7
# 5264 117.0195      662.1397        ralt     0.7301291 4.38         7
# 5265 117.0195      662.1397        lalt     0.5048710   NA         8
# 5266 117.0195      662.1397        lalt     0.5074726   NA         7
# 5267 117.0195      662.1397        lalt     0.4346458   NA        14
# 5268 117.0195      662.1397        ralt     0.6723947 3.21         8
# 5269 117.0195      662.1397        ralt     0.6673189 2.20         8
# 5270 117.0195      662.1397        ralt     0.6971004 3.41         7

# %%
all_dat |> print()
# Out:
# # A tibble: 5,270 x 18
#    participant_id item_nr condition  text     is_practice_trial resp  rt_ms
#    <chr>            <dbl> <chr>      <chr>    <lgl>             <chr> <dbl>
#  1 p015270              3 pseudoword Torrerk  TRUE              ralt   949.
#  2 p015270              3 word       korrekt  TRUE              ralt   714.
#  3 p015270              5 pseudoword tobreren TRUE              lalt  1017.
#  4 p015270              2 word       Mannes   TRUE              lalt   630.
#  5 p015270              4 word       sagt     TRUE              lalt   711.
#  6 p015270              1 word       Haie     TRUE              ralt   905.
#  7 p015270              4 pseudoword segt     TRUE              lalt  1308.
#  8 p015270              2 pseudoword sanzes   TRUE              lalt   643.
#  9 p015270              5 word       sicheren TRUE              ralt   703.
# 10 p015270              1 pseudoword Bage     TRUE              lalt   762.
# # i 5,260 more rows
# # i 11 more variables: time_so_far_secs <dbl>, age <dbl>, gender <chr>,
# #   dominant_hand <chr>, first_language <chr>, frame_rate_Hz <dbl>,
# #   total_time_secs <dbl>, corr_ans <chr>, snd <dbl>, ZipfSUBTLEX <dbl>,
# #   word_len <dbl>

# %% [markdown]
# ## Cleaning Data
#
# Now that we have the data loaded and all in one place, we need to exclude participants and trials that do not meet our exclusion criteria. This can be a useful step for (e.g.,) catching participants who were not paying attention, or removing outliers from your data.
#
# Before the experiment, I decided to exclude:
#
# * participants who had average accuracies <= 75% (too inaccurate)
#
# * participants who had median response times <250 ms (too fast)
#
# * participants who had median response times >1500 ms (too slow)
#
# * participants whose first language is not German
#
# * practice trials
#
# * trials responded to incorrectly (as we are interested in response times only in our analysis)
#
# #### 1: Calculate Accuracies
#
# First, let's create a column of participant accuracies. Wherever the `resp` column is equal to the `corr_ans` column, we will put a 1. Otherwise, we will put a zero.

# %%
all_dat <- mutate(all_dat, accuracy = ifelse(corr_ans == resp, 1, 0))

# %% [markdown]
# #### 2: Summarise Participants
#
# Now, we want to calculate per average response time and accuracy for each participant. Since response time is such a skewed distribution, we will calculate the median for response times.
#
# > Note: We include `first_language` in `group_by()` so that this is included in the per-participant summary, even though each participant has only one value.

# %%
participant_avg <- all_dat |>
  # exclude practice trials
  filter(!is_practice_trial) |>
  # then, for each participant, record their first language, and
  group_by(participant_id, first_language) |>
  # get their average RT and accuracy
  summarise(
    median_rt = median(rt_ms),
    mean_acc = mean(accuracy)
  ) |>
  # (often good practice to ungroup)
  ungroup()

participant_avg
# Out:
# `summarise()` has grouped output by 'participant_id'. You can override using the
# `.groups` argument.
#    participant_id first_language median_rt mean_acc
# 1  p015270        german         666.3243  0.9033333
# 2  p063288        german         700.6342  0.9500000
# 3  p072235        german         581.4319  0.8866667
# 4  p110412        german         532.8468  0.9266667
# 5  p153023        german         668.9906  0.9600000
# 6  p241074        german         757.0049  0.9133333
# 7  p255886        german         841.0861  0.9466667
# 8  p389724        german         768.3851  0.8933333
# 9  p445631        german         781.1020  0.9400000
# 10 p506691        german         698.2055  0.9200000
# 11 p532670        german         593.3490  0.9200000
# 12 p539652        german         696.6844  0.9800000
# 13 p551117        german         993.2718  0.9533333
# 14 p555715        german         712.3316  0.9066667
# 15 p596865        german         807.2578  0.9466667
# 16 p697533        german         660.9286  0.9000000
# 17 p813475        german         628.5290  0.9366667

# %%
participant_avg |> print()
# Out:
# # A tibble: 17 x 4
#    participant_id first_language median_rt mean_acc
#    <chr>          <chr>              <dbl>    <dbl>
#  1 p015270        german              666.    0.903
#  2 p063288        german              701.    0.95
#  3 p072235        german              581.    0.887
#  4 p110412        german              533.    0.927
#  5 p153023        german              669.    0.96
#  6 p241074        german              757.    0.913
#  7 p255886        german              841.    0.947
#  8 p389724        german              768.    0.893
#  9 p445631        german              781.    0.94
# 10 p506691        german              698.    0.92
# 11 p532670        german              593.    0.92
# 12 p539652        german              697.    0.98
# 13 p551117        german              993.    0.953
# 14 p555715        german              712.    0.907
# 15 p596865        german              807.    0.947
# 16 p697533        german              661.    0.9
# 17 p813475        german              629.    0.937

# %% [markdown]
# #### 3: Identify Good Participants
#
# Now, we can identify participants which are suitable for our hypotheses. When I originally designed the experiment, I decided to include:
#
# * only participants who had accuracies and response times within our cutoffs
#
# * only participants whose first language is German
#
# Here, we filter the dataframe of participant averages, and then make not of all the participants who meet our criteria. We store the list of good participants in `okay_participants`.
#
# > Note: the `pull()` function extracts data from a column, and puts it in a vector for us

# %%
okay_participants <- participant_avg |>
  filter(mean_acc>0.75, median_rt>=250, median_rt<1500, first_language=="german") |>
  pull(participant_id)

okay_participants
# Out:
#  [1] "p015270" "p063288" "p072235" "p110412" "p153023" "p241074" "p255886"
#  [8] "p389724" "p445631" "p506691" "p532670" "p539652" "p551117" "p555715"
# [15] "p596865" "p697533" "p813475"

# %% [markdown]
# #### 4: Clean Data
#
# Now we:
#
# * apply our participant exclusions
#
# * exclude trials that were responded to incorrectly
#
# * exclude practice trials
#
# We store the trials which we will use in the analysis in `trials_clean`

# %%
trials_clean <- all_dat |>
  filter(
    # only keep participants that meet inclusion criteria
    participant_id %in% okay_participants,
    # only keep correct trials
    accuracy == 1,
    # remove practice trials
    # (note: the exclamation mark ! can be read as "is not")
    !is_practice_trial
  )

# %% [markdown]
# ## Analysis - Frequency Effect
#
# Can we replicate the effect of frequency? Let's see what the effect of Zipf is on lexical decision response times!
#
# #### 1: Calculate Word Averages
#
# Here, we calculate the average RT and accuracy for each word. We also make sure that the Zipf values are brought through by including them in the `group_by()` function.

# %%
word_averages <- trials_clean |>
  filter(condition == "word") |>
  group_by(text, ZipfSUBTLEX) |>
  summarise(
    median_rt = median(rt_ms),
    mean_acc = mean(accuracy)
  ) |>
  ungroup()

word_averages
# Out:
# `summarise()` has grouped output by 'text'. You can override using the `.groups`
# argument.
#     text                 ZipfSUBTLEX median_rt mean_acc
# 1   Akzente              2.71         606.9888 1
# 2   Drücker              3.01         587.6378 1
# 3   Erwachsener          3.95         579.0646 1
# 4   Exorzisten           2.64         766.5383 1
# 5   Fabel                2.60         587.6363 1
# 6   Faulpelze            2.74         636.3171 1
# 7   Figuren              4.38         533.7726 1
# 8   Filigrane            1.90         806.2362 1
# 9   Geschicke            2.07         687.0766 1
# 10  Gondel               3.11         751.2169 1
# 11  Grabens              1.90         821.9062 1
# 12  Jugendfreund         2.55         712.2580 1
# 13  Kanaille             2.44        1123.2654 1
# 14  Kanäle               3.59         607.0342 1
# 15  Kollegium            2.67         609.3636 1
# 16  Konstitution         2.83         674.1628 1
# 17  Kontoauszug          2.29         621.6529 1
# 18  Kreuzzug             3.21         665.5666 1
# 19  Lobpreisung          1.90         765.7186 1
# 20  Maulwurf             3.68         580.3264 1
# 21  Media                4.30         585.7961 1
# 22  Miene                3.29         634.7190 1
# 23  Modepuppe            2.20         835.8671 1
# 24  Mühle                3.55         629.2869 1
# 25  Nachmittagen         2.07         812.4997 1
# 26  Parzellen            2.07         912.8653 1
# 27  Pocken               3.07         722.6228 1
# 28  Rasters              2.37         886.0890 1
# 29  Rechtswissenschaft   2.07         658.4950 1
# 30  Röntgen              3.53         678.5411 1
# ... ...                  ...         ...       ...
# 121 sogleich             2.94         569.1829 1
# 122 spuckten             2.44         622.8886 1
# 123 strammen             2.60         644.1684 1
# 124 sympathisierst       2.20         771.6291 1
# 125 telepathischen       2.29         853.3527 1
# 126 undurchdringbar      2.37         909.5223 1
# 127 ungesetzlich         2.83         652.3619 1
# 128 verantwortungsvollen 2.20         812.1853 1
# 129 vergeltet            2.07        1027.0431 1
# 130 verkürzen            3.01         714.4781 1
# 131 verschmutzen         2.74         669.5153 1
# 132 versteigere          1.90         621.8818 1
# 133 verzeichnet          3.19         591.5253 1
# 134 verzieren            2.50         906.0599 1
# 135 vorschriftswidrig    2.20        1091.5111 1
# 136 wahnsinnig           4.55         623.6735 1
# 137 wegkomme             2.85         602.1065 1
# 138 wissenschaftlicheren 2.07         737.2257 1
# 139 wunderbaren          3.87         622.3592 1
# 140 wundersamer          2.29         676.0379 1
# 141 wunderschöne         4.16         648.8343 1
# 142 zackiger             2.20         671.2383 1
# 143 zerrinnen            1.90         693.7648 1
# 144 zeugt                3.30         532.9791 1
# 145 zuflüstern           2.64         762.0226 1
# 146 zurechtgebogen       2.07         898.5075 1
# 147 zurückgeschreckt     1.90         915.3659 1
# 148 überbelegt           2.20         671.3488 1
# 149 überlebensgroße      1.90         949.4603 1
# 150 überlisten           3.33         739.7860 1

# %%
word_averages |> print()
# Out:
# # A tibble: 150 x 4
#    text        ZipfSUBTLEX median_rt mean_acc
#    <chr>             <dbl>     <dbl>    <dbl>
#  1 Akzente            2.71      607.        1
#  2 Drücker            3.01      588.        1
#  3 Erwachsener        3.95      579.        1
#  4 Exorzisten         2.64      767.        1
#  5 Fabel              2.6       588.        1
#  6 Faulpelze          2.74      636.        1
#  7 Figuren            4.38      534.        1
#  8 Filigrane          1.9       806.        1
#  9 Geschicke          2.07      687.        1
# 10 Gondel             3.11      751.        1
# # i 140 more rows

# %% [markdown]
# Clearly, accuracy is overall very high, but we have some variability in the response times.
#
# #### 2: Code the Frequency Variable
#
# Word frequency (`ZipfSUBTLEX`) is stored as a continuous variable. We can fit our model without doing any coding, but then it will be harder to interpret our model intercept. It is often useful to mean-centre variables, so that the model intercept can be interpreted as the grand average (e.g., the average RT overall).
#
# Let's calculate mean-centred Zipf frequency, and store in `ZipfSUBTLEX_cent`.

# %%
word_averages <- word_averages |>
  mutate(ZipfSUBTLEX_cent = ZipfSUBTLEX - mean(ZipfSUBTLEX))

# %% [markdown]
# #### 3: Estimate the Frequency Effect
#
# Now we can fit a linear model to predict average item response times as a function of mean-centred word frequency.

# %%
freq_mod <- lm(median_rt ~ ZipfSUBTLEX_cent, data = word_averages)

summary(freq_mod)
# Out:
# Call:
# lm(formula = median_rt ~ ZipfSUBTLEX_cent, data = word_averages)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -258.26  -82.43  -20.00   54.58  440.96
#
# Coefficients:
#                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)       704.978      9.516  74.087  < 2e-16 ***
# ZipfSUBTLEX_cent  -74.860      9.611  -7.789 1.09e-12 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 116.5 on 148 degrees of freedom
# Multiple R-squared:  0.2907,	Adjusted R-squared:  0.2859
# F-statistic: 60.66 on 1 and 148 DF,  p-value: 1.091e-12

# %% [markdown]
# This tells us that the average RT overall was 701.69 ms (*SE* = 9.4). The *t* value of 74.65 just reflects that this number is much larger than zero. We would report the overall average RT, but we probably wouldn't report the *t* and *p* values for this, since RT is almost by definition larger than zero.
#
# The second coefficient is more interesting. The $\Beta$ = -72.202 (*SE* = 9.49) tells us that for every one unit of Zipf, RT becomes 72.2 ms faster on average. This effect is significantly different from zero (*t*(148) = -7.61, *p* < .001).
#
# We might also want to report the R$^2$ value of .28, which means that our model is accounting for an estimated 28% of variance in the data.
#
# Finally, we might want to make a nice plot of the effect. We will be spending more time on this in a future session, but here is an example, showing the effect of frequency on response time.

# %%
word_averages |>
  ggplot(aes(ZipfSUBTLEX, median_rt)) +
  geom_point() +
  geom_smooth(method = "lm", formula = y~x) +
  labs(
    x = "Frequency (Zipf in SUBTLEX-DE)",
    y = "Median Response Time (ms)"
  )
# Out:
# plot without title

# %% [markdown]
# ## Analysis - SND Effects
#
# The main reason we ran this experiment, though, was to see whether we could replicate the interaction between Lexicality (word / pseudoword) and SND (semantic neighbourhood density).
#
# #### 1: Calculate Item Averages
#
# As before, we want to calculate average response times for each item. However, we also now want to include the pseudowords, as well as the words.
#
# We also want to include a step reported by Hendrix and Sun, who excluded items with an average accuracy of 66% or less.

# %%
stim_averages <- trials_clean |>
  # for every unique stimulus (text shown to the participant),
  # while also storing condition (lexicality) and SND,
  group_by(text, condition, snd) |>
  # get the average RT and accuracy
  summarise(
    median_rt = median(rt_ms),
    mean_acc = mean(accuracy)
  ) |>
  ungroup() |>
  # remove items with an average accuracy of <=.66
  filter(mean_acc > .66)
# Out:
# `summarise()` has grouped output by 'text', 'condition'. You can override using the
# `.groups` argument.

# %% [markdown]
# #### 2: Code Variables
#
# Again, we now want to code the variables.
#
# SND is a continuous variable, so we will mean-centre it (`snd_cent`). (We could also scale it if we wanted stardised coefficients.)
#
# Lexicality is a categorical variable, which we will deviation-code (`dev_lex`). If we had perfectly equal numbers of words and pseudowords in the data, we could just set this to `-0.5` and `0.5`. However, since we *might* have unequal numbers, to make sure that the variable is centred on zero, we first dummy code to 0 and 1, and then mean-centre it. As we happen to have equal numbers of stimuli, the values end up being `-0.5` and `0.5` anyway.

# %%
stim_averages <- stim_averages |>
  mutate(
    snd_cent = snd - mean(snd),
    dum_lex = ifelse(condition == "word", 1, 0),
    dev_lex = dum_lex - mean(dum_lex)
  )

stim_averages
# Out:
#     text                 condition  snd       median_rt mean_acc snd_cent
# 1   Abgegöbe             pseudoword 0.6138101  840.7127 1         0.01042202
# 2   Akzente              word       0.7164028  606.9888 1         0.11301472
# 3   Austerbafer          pseudoword 0.6162724  808.8113 1         0.01288432
# 4   Bünktchen            pseudoword 0.5853792  994.7072 1        -0.01800880
# 5   Cermelen             pseudoword 0.5477454  672.8177 1        -0.05564265
# 6   Drücker              word       0.5730488  587.6378 1        -0.03033925
# 7   Durchszelten         pseudoword 0.5671816 1171.4299 1        -0.03620647
# 8   Erwachsener          word       0.6809480  579.0646 1         0.07755998
# 9   Exorzisten           word       0.6235078  766.5383 1         0.02011979
# 10  Exzingsener          pseudoword 0.5324633  832.0553 1        -0.07092476
# 11  Fabel                word       0.6343845  587.6363 1         0.03099644
# 12  Faulpelze            word       0.5894609  636.3171 1        -0.01392714
# 13  Figuren              word       0.7301291  533.7726 1         0.12674103
# 14  Filigrane            word       0.6749975  806.2362 1         0.07160946
# 15  Gamäse               pseudoword 0.5696685  654.3057 1        -0.03371957
# 16  Geschicke            word       0.4512565  687.0766 1        -0.15213153
# 17  Gisiblase            pseudoword 0.5315044  628.4009 1        -0.07188368
# 18  Gondel               word       0.6947889  751.2169 1         0.09140090
# 19  Gowuren              pseudoword 0.5398612  641.0455 1        -0.06352678
# 20  Grabens              word       0.7030543  821.9062 1         0.09966627
# 21  Hahnzusachen         pseudoword 0.4805572 1052.9840 1        -0.12283086
# 22  Hasteln              pseudoword 0.5570527 1175.8561 1        -0.04633534
# 23  Horke                pseudoword 0.5920526  773.9996 1        -0.01133546
# 24  Jespelanges          pseudoword 0.5640034  658.5409 1        -0.03938466
# 25  Jugendfreund         word       0.6942410  712.2580 1         0.09085295
# 26  Kahästle             pseudoword 0.5502094  590.1206 1        -0.05317862
# 27  Kanaille             word       0.6233634 1123.2654 1         0.01997535
# 28  Kanäle               word       0.7313112  607.0342 1         0.12792316
# 29  Klauchrertig         pseudoword 0.5380428  743.3048 1        -0.06534519
# 30  Knolto               pseudoword 0.5444923  670.3125 1        -0.05889578
# ... ...                  ...        ...       ...       ...      ...
# 271 verzieren            word       0.7263222  906.0599 1         0.1229341398
# 272 vezönlerten          pseudoword 0.5251437  697.4655 1        -0.0782443632
# 273 vorschrenntgadrig    pseudoword 0.5339742  817.5949 1        -0.0694138159
# 274 vorschriftswidrig    word       0.6031698 1091.5111 1        -0.0002182593
# 275 wafspiges            pseudoword 0.6185039  603.0856 1         0.0151158701
# 276 wahnsinnig           word       0.8447705  623.6735 1         0.2413824211
# 277 wegkomme             word       0.6856961  602.1065 1         0.0823081146
# 278 werillen             pseudoword 0.4399825  602.7662 1        -0.1634055664
# 279 weutamme             pseudoword 0.4449381  623.4207 1        -0.1584499707
# 280 wissenschaftlicheren word       0.7608551  737.2257 1         0.1574670921
# 281 wondrinnig           pseudoword 0.4723154  667.1523 1        -0.1310726334
# 282 wunderbaren          word       0.8764615  622.3592 1         0.2730734239
# 283 wundersamer          word       0.6839779  676.0379 1         0.0805898200
# 284 wunderschöne         word       0.8831501  648.8343 1         0.2797620426
# 285 zackiger             word       0.6673189  671.2383 1         0.0639308940
# 286 zatz                 pseudoword 0.4191390  638.0601 1        -0.1842490603
# 287 zeggt                pseudoword 0.5036876  678.0159 1        -0.0997004439
# 288 zerfanken            pseudoword 0.5328117  741.4086 1        -0.0705763091
# 289 zerrinnen            word       0.6125055  693.7648 1         0.0091174970
# 290 zeugt                word       0.6530934  532.9791 1         0.0497053395
# 291 zuflüstern           word       0.7208457  762.0226 1         0.1174577008
# 292 zunandsgewägen       pseudoword 0.3937071  924.7140 1        -0.2096809079
# 293 zurechtgebogen       word       0.6257972  898.5075 1         0.0224091898
# 294 zurichgeschrafst     pseudoword 0.4287635  850.3952 1        -0.1746245434
# 295 zurückgeschreckt     word       0.6647302  915.3659 1         0.0613421212
# 296 zürgiger             pseudoword 0.6080680  710.6605 1         0.0046799908
# 297 überbelegt           word       0.6246822  671.3488 1         0.0212941776
# 298 überlebensgroße      word       0.7568407  949.4603 1         0.1534527074
# 299 überlefätsglave      pseudoword 0.6315054  702.5207 1         0.0281173597
# 300 überlisten           word       0.6474396  739.7860 1         0.0440515528
#     dum_lex dev_lex
# 1   0       -0.5
# 2   1        0.5
# 3   0       -0.5
# 4   0       -0.5
# 5   0       -0.5
# 6   1        0.5
# 7   0       -0.5
# 8   1        0.5
# 9   1        0.5
# 10  0       -0.5
# 11  1        0.5
# 12  1        0.5
# 13  1        0.5
# 14  1        0.5
# 15  0       -0.5
# 16  1        0.5
# 17  0       -0.5
# 18  1        0.5
# 19  0       -0.5
# 20  1        0.5
# 21  0       -0.5
# 22  0       -0.5
# 23  0       -0.5
# 24  0       -0.5
# 25  1        0.5
# 26  0       -0.5
# 27  1        0.5
# 28  1        0.5
# 29  0       -0.5
# 30  0       -0.5
# ... ...     ...
# 271 1        0.5
# 272 0       -0.5
# 273 0       -0.5
# 274 1        0.5
# 275 0       -0.5
# 276 1        0.5
# 277 1        0.5
# 278 0       -0.5
# 279 0       -0.5
# 280 1        0.5
# 281 0       -0.5
# 282 1        0.5
# 283 1        0.5
# 284 1        0.5
# 285 1        0.5
# 286 0       -0.5
# 287 0       -0.5
# 288 0       -0.5
# 289 1        0.5
# 290 1        0.5
# 291 1        0.5
# 292 0       -0.5
# 293 1        0.5
# 294 0       -0.5
# 295 1        0.5
# 296 0       -0.5
# 297 1        0.5
# 298 1        0.5
# 299 0       -0.5
# 300 1        0.5

# %%
stim_averages |> print()
# Out:
# # A tibble: 300 x 8
#    text         condition    snd median_rt mean_acc snd_cent dum_lex dev_lex
#    <chr>        <chr>      <dbl>     <dbl>    <dbl>    <dbl>   <dbl>   <dbl>
#  1 Abgegöbe     pseudoword 0.614      841.        1   0.0104       0    -0.5
#  2 Akzente      word       0.716      607.        1   0.113        1     0.5
#  3 Austerbafer  pseudoword 0.616      809.        1   0.0129       0    -0.5
#  4 Bünktchen    pseudoword 0.585      995.        1  -0.0180       0    -0.5
#  5 Cermelen     pseudoword 0.548      673.        1  -0.0556       0    -0.5
#  6 Drücker      word       0.573      588.        1  -0.0303       1     0.5
#  7 Durchszelten pseudoword 0.567     1171.        1  -0.0362       0    -0.5
#  8 Erwachsener  word       0.681      579.        1   0.0776       1     0.5
#  9 Exorzisten   word       0.624      767.        1   0.0201       1     0.5
# 10 Exzingsener  pseudoword 0.532      832.        1  -0.0709       0    -0.5
# # i 290 more rows

# %% [markdown]
# ## 3: Estimate the Lexicality × SND Interaction
#
# Here we fit the model. Note that, unlike with frequency, it's up to you to interpret this one!

# %%
main_mod <- lm(median_rt ~ dev_lex * snd_cent, data = stim_averages)

summary(main_mod)
# Out:
# Call:
# lm(formula = median_rt ~ dev_lex * snd_cent, data = stim_averages)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -227.98 -104.34  -41.63   74.04  505.62
#
# Coefficients:
#                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)        763.02      13.31  57.310  < 2e-16 ***
# dev_lex            -73.46      26.63  -2.759  0.00616 **
# snd_cent            93.35     134.25   0.695  0.48741
# dev_lex:snd_cent  -735.12     268.50  -2.738  0.00656 **
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 143.2 on 296 degrees of freedom
# Multiple R-squared:  0.06398,	Adjusted R-squared:  0.05449
# F-statistic: 6.744 on 3 and 296 DF,  p-value: 0.000205

# %% [markdown]
# Finally, here is a plot showing the effect of SND for each lexicality condition.

# %%
stim_averages |>
  ggplot(aes(snd, median_rt, colour=condition)) +
  geom_point(alpha = 0.33) +  # alpha sets point transparency
  geom_smooth(method = "lm", formula = y ~ x) +
  labs(
    x = "Semantic Neighbourhood Density",
    y = "Median Response Time (ms)",
    colour = "Lexicality"
  )
# Out:
# plot without title
